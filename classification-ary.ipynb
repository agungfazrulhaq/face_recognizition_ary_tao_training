# %% [markdown]
# ### 0. PREPARING ENVIRONMENT VARIABLE

# %%
# Setting up env variables for cleaner command line commands.
import os

# %env KEY=nvidia_tlt
# %env NUM_GPUS=1
# %env USER_EXPERIMENT_DIR=/workspace/faceclassification
# %env DATA_DOWNLOAD_DIR=/workspace/data

# Set this path if you don't run the notebook from the samples directory.
# %env NOTEBOOK_ROOT=~/tao-samples/classification

# Please define this local project directory that needs to be mapped to the TAO docker session.
# The dataset expected to be present in $LOCAL_PROJECT_DIR/data, while the results for the steps
# in this notebook will be stored at $LOCAL_PROJECT_DIR/classification
# !PLEASE MAKE SURE TO UPDATE THIS PATH!.
os.environ["LOCAL_PROJECT_DIR"] = "/workspace"

os.environ["LOCAL_DATA_DIR"] = os.path.join(
    os.getenv("LOCAL_PROJECT_DIR", os.getcwd()),
    "data"
)
os.environ["LOCAL_EXPERIMENT_DIR"] = os.path.join(
    os.getenv("LOCAL_PROJECT_DIR", os.getcwd()),
    "faceclassification"
)

# The sample spec files are present in the same path as the downloaded samples.
os.environ["LOCAL_SPECS_DIR"] = os.path.join(
    os.getenv("LOCAL_EXPERIMENT_DIR", os.getcwd()),
    "specs"
)
# %env SPECS_DIR=/workspace/faceclassification/specs

# Showing list of specification files.
# !ls -rlt $LOCAL_SPECS_DIR
# Out:
# env: KEY=nvidia_tlt
# env: NUM_GPUS=1
# env: USER_EXPERIMENT_DIR=/workspace/faceclassification
# env: DATA_DOWNLOAD_DIR=/workspace/data
# env: SPECS_DIR=/workspace/faceclassification/specs
# total 12
# -rw-r--r-- 1 root root 1272 Aug  8 04:51 classification_spec.cfg
# -rw-r--r-- 1 root root 1142 Aug  8 04:51 classification_retrain_spec.cfg
# -rw-r--r-- 1 root root 1247 Aug  9 04:03 classification_mobilenet.cfg

# %%
# Mapping up the local directories to the TAO docker.
import json
import os
mounts_file = os.path.expanduser("~/.tao_mounts.json")

# Define the dictionary with the mapped drives
drive_map = {
    "Mounts": [
        # Mapping the data directory
        {
            "source": os.environ["LOCAL_PROJECT_DIR"],
            "destination": "/workspace"
        },
        # Mapping the specs directory.
        {
            "source": os.environ["LOCAL_SPECS_DIR"],
            "destination": os.environ["SPECS_DIR"]
        },
    ],
    "DockerOptions":{
        "user": "{}:{}".format(os.getuid(), os.getgid())
    }
}

# Writing the mounts file.
with open(mounts_file, "w") as mfile:
    json.dump(drive_map, mfile, indent=4)

# %%
# !cat ~/.tao_mounts.json
# Out:
# {
#     "Mounts": [
#         {
#             "source": "/workspace",
#             "destination": "/workspace"
#         },
#         {
#             "source": "/workspace/faceclassification/specs",
#             "destination": "/workspace/faceclassification/specs"
#         }
#     ],
#     "DockerOptions": {
#         "user": "0:0"
#     }
# }

# %%
# !tao info
# Out:
# Configuration of the TAO Toolkit Instance
# dockers: ['nvidia/tao/tao-toolkit-tf', 'nvidia/tao/tao-toolkit-pyt', 'nvidia/tao/tao-toolkit-lm']
# format_version: 2.0
# toolkit_version: 3.22.05
# published_date: 05/25/2022

# %% [markdown]
# ### 1. DATASET PREPARATION

# %% [markdown]
# #### 1.1 Downloading Pre-Trained Model

# %%
# Installing NGC CLI on the local machine.
## Download and install
# %env CLI=ngccli_cat_linux.zip
# !mkdir -p $LOCAL_PROJECT_DIR/ngccli

# Remove any previously existing CLI installations
# !rm -rf $LOCAL_PROJECT_DIR/ngccli/*
# !wget "https://ngc.nvidia.com/downloads/$CLI" -P $LOCAL_PROJECT_DIR/ngccli
# !unzip -u "$LOCAL_PROJECT_DIR/ngccli/$CLI" -d $LOCAL_PROJECT_DIR/ngccli/
# !rm $LOCAL_PROJECT_DIR/ngccli/*.zip 
os.environ["PATH"]="{}/ngccli:{}".format(os.getenv("LOCAL_PROJECT_DIR", ""), os.getenv("PATH", ""))
# Out:
# env: CLI=ngccli_cat_linux.zip
# --2022-08-08 06:21:57--  https://ngc.nvidia.com/downloads/ngccli_cat_linux.zip
# Resolving ngc.nvidia.com (ngc.nvidia.com)... 52.84.251.128, 52.84.251.90, 52.84.251.5, ...
# Connecting to ngc.nvidia.com (ngc.nvidia.com)|52.84.251.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33992208 (32M) [application/zip]
# Saving to: ‘/workspace/ngccli/ngccli_cat_linux.zip’
#
# ngccli_cat_linux.zi 100%[===================>]  32.42M  3.34MB/s    in 7.5s
#
# 2022-08-08 06:22:10 (4.34 MB/s) - ‘/workspace/ngccli/ngccli_cat_linux.zip’ saved [33992208/33992208]
#
# Archive:  /workspace/ngccli/ngccli_cat_linux.zip
#    creating: /workspace/ngccli/ngc-cli/
#    creating: /workspace/ngccli/ngc-cli/multidict/
#   inflating: /workspace/ngccli/ngc-cli/multidict/_multidict.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/libpython3.9.so.1.0
#   inflating: /workspace/ngccli/ngc-cli/libkrb5support.so.0
#   inflating: /workspace/ngccli/ngc-cli/libgssapi_krb5.so.2
#  extracting: /workspace/ngccli/ngc-cli/base_library.zip
#    creating: /workspace/ngccli/ngc-cli/certifi/
#   inflating: /workspace/ngccli/ngc-cli/certifi/cacert.pem
#   inflating: /workspace/ngccli/ngc-cli/libfreebl3.so
#   inflating: /workspace/ngccli/ngc-cli/libgcc_s.so.1
#   inflating: /workspace/ngccli/ngc-cli/libkeyutils.so.1
#   inflating: /workspace/ngccli/ngc-cli/libcom_err.so.2
#   inflating: /workspace/ngccli/ngc-cli/libcrypto.so.10
#   inflating: /workspace/ngccli/ngc-cli/libffi.so.6
#    creating: /workspace/ngccli/ngc-cli/cryptography/
#    creating: /workspace/ngccli/ngc-cli/cryptography/hazmat/
#    creating: /workspace/ngccli/ngc-cli/cryptography/hazmat/bindings/
#   inflating: /workspace/ngccli/ngc-cli/cryptography/hazmat/bindings/_rust.abi3.so
#   inflating: /workspace/ngccli/ngc-cli/cryptography/hazmat/bindings/_openssl.abi3.so
#    creating: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/
#  extracting: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/WHEEL
#   inflating: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/direct_url.json
#  extracting: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/REQUESTED
#  extracting: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/top_level.txt
#  extracting: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/INSTALLER
#   inflating: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/RECORD
#   inflating: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/METADATA
#   inflating: /workspace/ngccli/ngc-cli/prettytable-2.0.0.dist-info/COPYING
#    creating: /workspace/ngccli/ngc-cli/thrift/
#    creating: /workspace/ngccli/ngc-cli/thrift/protocol/
#   inflating: /workspace/ngccli/ngc-cli/thrift/protocol/fastbinary.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/libz.so.1
#   inflating: /workspace/ngccli/ngc-cli/libstdc++.so.6
#   inflating: /workspace/ngccli/ngc-cli/libk5crypto.so.3
#    creating: /workspace/ngccli/ngc-cli/psutil/
#   inflating: /workspace/ngccli/ngc-cli/psutil/_psutil_posix.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/psutil/_psutil_linux.cpython-39-x86_64-linux-gnu.so
#    creating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/WHEEL
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/LICENSE.APACHE
#  extracting: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/top_level.txt
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/LICENSE
#  extracting: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/INSTALLER
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/LICENSE.PSF
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/LICENSE.BSD
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/RECORD
#   inflating: /workspace/ngccli/ngc-cli/cryptography-36.0.1.dist-info/METADATA
#   inflating: /workspace/ngccli/ngc-cli/libselinux.so.1
#   inflating: /workspace/ngccli/ngc-cli/libkrb5.so.3
#    creating: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/
#   inflating: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/WHEEL
#   inflating: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/direct_url.json
#  extracting: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/REQUESTED
#  extracting: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/top_level.txt
#   inflating: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/LICENSE
#  extracting: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/namespace_packages.txt
#  extracting: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/INSTALLER
#   inflating: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/RECORD
#   inflating: /workspace/ngccli/ngc-cli/google_api_core-2.2.2.dist-info/METADATA
#    creating: /workspace/ngccli/ngc-cli/aiohttp/
#   inflating: /workspace/ngccli/ngc-cli/aiohttp/_http_writer.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/aiohttp/_websocket.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/aiohttp/_helpers.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/aiohttp/_http_parser.cpython-39-x86_64-linux-gnu.so
#    creating: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/
#   inflating: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/WHEEL
#   inflating: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/direct_url.json
#  extracting: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/REQUESTED
#  extracting: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/top_level.txt
#   inflating: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/LICENSE
#  extracting: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/INSTALLER
#   inflating: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/RECORD
#   inflating: /workspace/ngccli/ngc-cli/jsonpickle-2.0.0.dist-info/METADATA
#    creating: /workspace/ngccli/ngc-cli/wcwidth/
#   inflating: /workspace/ngccli/ngc-cli/wcwidth/version.json
#   inflating: /workspace/ngccli/ngc-cli/ngc
#    creating: /workspace/ngccli/ngc-cli/yarl/
#   inflating: /workspace/ngccli/ngc-cli/yarl/_quoting_c.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/_cffi_backend.cpython-39-x86_64-linux-gnu.so
#    creating: /workspace/ngccli/ngc-cli/google/
#    creating: /workspace/ngccli/ngc-cli/google/protobuf/
#    creating: /workspace/ngccli/ngc-cli/google/protobuf/pyext/
#   inflating: /workspace/ngccli/ngc-cli/google/protobuf/pyext/_message.cpython-39-x86_64-linux-gnu.so
#    creating: /workspace/ngccli/ngc-cli/google/protobuf/internal/
#   inflating: /workspace/ngccli/ngc-cli/google/protobuf/internal/_api_implementation.cpython-39-x86_64-linux-gnu.so
#    creating: /workspace/ngccli/ngc-cli/lib-dynload/
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/mmap.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_opcode.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/termios.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_codecs_jp.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_md5.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_hashlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_codecs_iso2022.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_socket.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/fcntl.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_elementtree.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_queue.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/select.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/resource.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_csv.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_codecs_tw.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_statistics.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_heapq.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_ssl.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_pickle.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/array.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_sha1.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/binascii.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_sha512.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/math.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_random.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_contextvars.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/zlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_posixsubprocess.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_datetime.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_struct.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_codecs_kr.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_multiprocessing.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_sha256.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/unicodedata.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_codecs_cn.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_json.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/grp.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_posixshmem.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_bisect.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_codecs_hk.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_blake2.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/pyexpat.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_decimal.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_sha3.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_multibytecodec.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/lib-dynload/_asyncio.cpython-39-x86_64-linux-gnu.so
#    creating: /workspace/ngccli/ngc-cli/botocore/
#   inflating: /workspace/ngccli/ngc-cli/botocore/cacert.pem
#    creating: /workspace/ngccli/ngc-cli/botocore/data/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint/2016-12-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/s3outposts/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/s3outposts/2017-07-25/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/resource-groups/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/resource-groups/2017-11-27/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/translate/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/translate/2017-07-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/translate/2017-07-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/translate/2017-07-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/translate/2017-07-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/detective/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/detective/2018-10-26/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/detective/2018-10-26/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/detective/2018-10-26/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/amplify/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/amplify/2017-07-25/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amplify/2017-07-25/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amplify/2017-07-25/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/codecommit/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/codecommit/2015-04-13/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codecommit/2015-04-13/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codecommit/2015-04-13/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codecommit/2015-04-13/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/macie2/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/macie2/2020-01-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/macie2/2020-01-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/macie2/2020-01-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/devops-guru/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/devops-guru/2020-12-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/devops-guru/2020-12-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/devops-guru/2020-12-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/amp/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/amp/2020-08-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amp/2020-08-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amp/2020-08-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amp/2020-08-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/snowball/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/snowball/2016-06-30/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/snowball/2016-06-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/snowball/2016-06-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/snowball/2016-06-30/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/wellarchitected/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/wellarchitected/2020-03-31/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/wellarchitected/2020-03-31/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/wellarchitected/2020-03-31/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint-sms-voice/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint-sms-voice/2018-09-05/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/pinpoint-sms-voice/2018-09-05/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudhsm/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudhsm/2014-05-30/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudhsm/2014-05-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudhsm/2014-05-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudhsm/2014-05-30/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotdeviceadvisor/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/health/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/health/2016-08-04/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/health/2016-08-04/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/health/2016-08-04/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/health/2016-08-04/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mturk/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mturk/2017-01-17/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mturk/2017-01-17/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mturk/2017-01-17/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mturk/2017-01-17/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mediastore-data/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mediastore-data/2017-09-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediastore-data/2017-09-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediastore-data/2017-09-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediastore-data/2017-09-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/comprehendmedical/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/comprehendmedical/2018-10-30/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/comprehendmedical/2018-10-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/comprehendmedical/2018-10-30/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/groundstation/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/groundstation/2019-05-23/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/groundstation/2019-05-23/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/groundstation/2019-05-23/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/storagegateway/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/storagegateway/2013-06-30/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/storagegateway/2013-06-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/storagegateway/2013-06-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/storagegateway/2013-06-30/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/appsync/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/appsync/2017-07-25/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/appsync/2017-07-25/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/appsync/2017-07-25/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/appsync/2017-07-25/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/events/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/events/2014-02-03/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/events/2014-02-03/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/events/2015-10-07/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/events/2015-10-07/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/events/2015-10-07/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/events/2015-10-07/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/textract/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/textract/2018-06-27/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/textract/2018-06-27/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/textract/2018-06-27/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/workmail/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/workmail/2017-10-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/workmail/2017-10-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/workmail/2017-10-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/workmail/2017-10-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/guardduty/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/guardduty/2017-11-28/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/guardduty/2017-11-28/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/guardduty/2017-11-28/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/chime-sdk-identity/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/chime-sdk-identity/2021-04-20/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/chime-sdk-identity/2021-04-20/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/chime-sdk-identity/2021-04-20/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/redshift-data/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/redshift-data/2019-12-20/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/redshift-data/2019-12-20/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/redshift-data/2019-12-20/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/redshift-data/2019-12-20/paginators-1.sdk-extras.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iam/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iam/2010-05-08/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iam/2010-05-08/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iam/2010-05-08/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iam/2010-05-08/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iam/2010-05-08/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2014-09-30/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2014-09-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2014-09-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2014-09-30/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2015-02-02/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2015-02-02/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2015-02-02/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2015-02-02/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elasticache/2015-02-02/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lookoutmetrics/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lookoutmetrics/2017-07-25/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/lookoutmetrics/2017-07-25/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lookoutmetrics/2017-07-25/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/schemas/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/schemas/2019-12-02/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/schemas/2019-12-02/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/schemas/2019-12-02/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/schemas/2019-12-02/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/amplifybackend/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/amplifybackend/2020-08-11/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amplifybackend/2020-08-11/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/amplifybackend/2020-08-11/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/servicediscovery/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/servicediscovery/2017-03-14/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/servicediscovery/2017-03-14/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/servicediscovery/2017-03-14/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/servicediscovery/2017-03-14/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/dlm/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/dlm/2018-01-12/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/dlm/2018-01-12/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/dlm/2018-01-12/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/dlm/2018-01-12/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/appconfig/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/appconfig/2019-10-09/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/appconfig/2019-10-09/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/appconfig/2019-10-09/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lambda/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2014-11-11/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2014-11-11/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2015-03-31/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2015-03-31/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2015-03-31/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2015-03-31/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lambda/2015-03-31/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/opsworkscm/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/opsworkscm/2016-11-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/opsworkscm/2016-11-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/opsworkscm/2016-11-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/opsworkscm/2016-11-01/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/opsworkscm/2016-11-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sso-admin/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sso-admin/2020-07-20/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sso-admin/2020-07-20/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sso-admin/2020-07-20/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sagemaker/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sagemaker/2017-07-24/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sagemaker/2017-07-24/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sagemaker/2017-07-24/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sagemaker/2017-07-24/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sagemaker/2017-07-24/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/budgets/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/budgets/2016-10-20/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/budgets/2016-10-20/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/budgets/2016-10-20/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/budgets/2016-10-20/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearchdomain/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearchdomain/2013-01-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearchdomain/2013-01-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearchdomain/2013-01-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/connect/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/connect/2017-08-08/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/connect/2017-08-08/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/connect/2017-08-08/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/connect/2017-08-08/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/acm/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/acm/2015-12-08/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/acm/2015-12-08/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/acm/2015-12-08/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/acm/2015-12-08/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/acm/2015-12-08/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/service-quotas/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/service-quotas/2019-06-24/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/service-quotas/2019-06-24/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/service-quotas/2019-06-24/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/elastic-inference/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/elastic-inference/2017-07-25/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elastic-inference/2017-07-25/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/elastic-inference/2017-07-25/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/workmailmessageflow/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/organizations/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/organizations/2016-11-28/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/organizations/2016-11-28/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/organizations/2016-11-28/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/organizations/2016-11-28/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotthingsgraph/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotthingsgraph/2018-09-06/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotthingsgraph/2018-09-06/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotthingsgraph/2018-09-06/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/shield/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/shield/2016-06-02/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/shield/2016-06-02/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/shield/2016-06-02/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/shield/2016-06-02/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/application-autoscaling/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/application-autoscaling/2016-02-06/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/application-autoscaling/2016-02-06/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/application-autoscaling/2016-02-06/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/application-autoscaling/2016-02-06/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/securityhub/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/securityhub/2018-10-26/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/securityhub/2018-10-26/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/securityhub/2018-10-26/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotfleethub/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotfleethub/2020-11-03/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotfleethub/2020-11-03/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotfleethub/2020-11-03/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/dynamodbstreams/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/dynamodbstreams/2012-08-10/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/dynamodbstreams/2012-08-10/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/dynamodbstreams/2012-08-10/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/dynamodbstreams/2012-08-10/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/codeguru-reviewer/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/codeguru-reviewer/2019-09-19/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codeguru-reviewer/2019-09-19/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codeguru-reviewer/2019-09-19/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codeguru-reviewer/2019-09-19/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/nimble/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/nimble/2020-08-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/nimble/2020-08-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/nimble/2020-08-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/nimble/2020-08-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/marketplace-entitlement/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/marketplace-entitlement/2017-01-11/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/marketplace-entitlement/2017-01-11/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/marketplace-entitlement/2017-01-11/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/marketplace-entitlement/2017-01-11/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/kinesis-video-media/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/kinesis-video-media/2017-09-30/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/kinesis-video-media/2017-09-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/kinesis-video-media/2017-09-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/kinesis-video-media/2017-09-30/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/license-manager/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/license-manager/2018-08-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/license-manager/2018-08-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/license-manager/2018-08-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearch/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearch/2011-02-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearch/2011-02-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearch/2013-01-01/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/cloudsearch/2013-01-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudsearch/2013-01-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/connect-contact-lens/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/connect-contact-lens/2020-08-21/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/connect-contact-lens/2020-08-21/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/connect-contact-lens/2020-08-21/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/apigateway/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/apigateway/2015-07-09/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/apigateway/2015-07-09/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/apigateway/2015-07-09/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/apigateway/2015-07-09/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/route53-recovery-cluster/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/route53-recovery-cluster/2019-12-02/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/route53-recovery-cluster/2019-12-02/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/route53-recovery-cluster/2019-12-02/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/codestar-notifications/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/codestar-notifications/2019-10-15/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codestar-notifications/2019-10-15/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/codestar-notifications/2019-10-15/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotsitewise/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotsitewise/2019-12-02/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotsitewise/2019-12-02/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotsitewise/2019-12-02/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotsitewise/2019-12-02/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/machinelearning/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/machinelearning/2014-12-12/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/machinelearning/2014-12-12/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/machinelearning/2014-12-12/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/machinelearning/2014-12-12/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/machinelearning/2014-12-12/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/comprehend/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/comprehend/2017-11-27/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/comprehend/2017-11-27/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/comprehend/2017-11-27/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/comprehend/2017-11-27/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ds/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ds/2015-04-16/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ds/2015-04-16/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ds/2015-04-16/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ds/2015-04-16/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/greengrass/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/greengrass/2017-06-07/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/greengrass/2017-06-07/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/greengrass/2017-06-07/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/secretsmanager/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/secretsmanager/2017-10-17/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/secretsmanager/2017-10-17/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/secretsmanager/2017-10-17/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/secretsmanager/2017-10-17/examples-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/secretsmanager/2017-10-17/service-2.sdk-extras.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sns/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sns/2010-03-31/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sns/2010-03-31/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sns/2010-03-31/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sns/2010-03-31/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/kinesisvideo/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/kinesisvideo/2017-09-30/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/kinesisvideo/2017-09-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/kinesisvideo/2017-09-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/kinesisvideo/2017-09-30/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/glacier/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/glacier/2012-06-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/glacier/2012-06-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/glacier/2012-06-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/glacier/2012-06-01/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/glacier/2012-06-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lexv2-models/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/lexv2-models/2020-08-07/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/lexv2-models/2020-08-07/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lexv2-models/2020-08-07/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/lexv2-models/2020-08-07/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/forecastquery/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/forecastquery/2018-06-26/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/forecastquery/2018-06-26/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/forecastquery/2018-06-26/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mediaconvert/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mediaconvert/2017-08-29/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediaconvert/2017-08-29/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediaconvert/2017-08-29/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sso/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/sso/2019-06-10/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sso/2019-06-10/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/sso/2019-06-10/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/forecast/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/forecast/2018-06-26/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/forecast/2018-06-26/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/forecast/2018-06-26/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/robomaker/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/robomaker/2018-06-29/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/robomaker/2018-06-29/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/robomaker/2018-06-29/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-10-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-10-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-10-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-10-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-09-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-09-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-09-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2014-09-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-11-15/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-11-15/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-11-15/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-11-15/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-11-15/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-03-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-03-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-03-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-03-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-10-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-10-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-10-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-10-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-04-15/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-04-15/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-04-15/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2015-04-15/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-04-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-04-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-04-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-04-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-09-15/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-09-15/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-09-15/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-09-15/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ec2/2016-09-15/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/network-firewall/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/network-firewall/2020-11-12/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/network-firewall/2020-11-12/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/network-firewall/2020-11-12/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mediapackage-vod/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/mediapackage-vod/2018-11-07/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediapackage-vod/2018-11-07/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/mediapackage-vod/2018-11-07/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/wisdom/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/wisdom/2020-10-19/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/wisdom/2020-10-19/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/wisdom/2020-10-19/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/proton/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/proton/2020-07-20/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/proton/2020-07-20/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/proton/2020-07-20/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/proton/2020-07-20/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/macie/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/macie/2017-12-19/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/macie/2017-12-19/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/macie/2017-12-19/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/macie/2017-12-19/examples-1.json
# ...
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-09-07/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-09-07/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-10-21/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-10-21/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-10-21/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-10-21/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2020-05-31/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2020-05-31/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2020-05-31/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2020-05-31/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2020-05-31/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-04-17/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-04-17/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-04-17/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-04-17/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-20/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-20/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-20/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-20/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-13/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-13/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-13/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-13/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2016-08-01/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2017-10-30/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2017-10-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2017-10-30/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2017-10-30/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2017-10-30/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-05-31/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-05-31/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-05-31/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cloudfront/2014-05-31/waiters-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/fis/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/fis/2020-12-01/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/fis/2020-12-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/fis/2020-12-01/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/frauddetector/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/frauddetector/2019-11-15/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/frauddetector/2019-11-15/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/frauddetector/2019-11-15/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ram/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ram/2018-01-04/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ram/2018-01-04/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ram/2018-01-04/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cognito-idp/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/cognito-idp/2016-04-18/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cognito-idp/2016-04-18/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cognito-idp/2016-04-18/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/cognito-idp/2016-04-18/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ssm/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/ssm/2014-11-06/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ssm/2014-11-06/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ssm/2014-11-06/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ssm/2014-11-06/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/ssm/2014-11-06/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/personalize-events/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/personalize-events/2018-03-22/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/personalize-events/2018-03-22/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/personalize-events/2018-03-22/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/datasync/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/datasync/2018-11-09/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/datasync/2018-11-09/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/datasync/2018-11-09/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/emr/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/emr/2009-03-31/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/emr/2009-03-31/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/emr/2009-03-31/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/emr/2009-03-31/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/emr/2009-03-31/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/polly/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/polly/2016-06-10/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/polly/2016-06-10/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/polly/2016-06-10/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/polly/2016-06-10/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotevents/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotevents/2018-07-27/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/iotevents/2018-07-27/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotevents/2018-07-27/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/s3/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/s3/2006-03-01/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/s3/2006-03-01/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/s3/2006-03-01/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/s3/2006-03-01/waiters-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/s3/2006-03-01/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotwireless/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/iotwireless/2020-11-22/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/iotwireless/2020-11-22/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/iotwireless/2020-11-22/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/batch/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/batch/2016-08-10/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/batch/2016-08-10/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/batch/2016-08-10/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/batch/2016-08-10/examples-1.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/networkmanager/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/networkmanager/2019-07-05/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/networkmanager/2019-07-05/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/networkmanager/2019-07-05/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/migrationhub-config/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/migrationhub-config/2019-06-30/
#  extracting: /workspace/ngccli/ngc-cli/botocore/data/migrationhub-config/2019-06-30/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/migrationhub-config/2019-06-30/service-2.json
#    creating: /workspace/ngccli/ngc-cli/botocore/data/personalize/
#    creating: /workspace/ngccli/ngc-cli/botocore/data/personalize/2018-05-22/
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/personalize/2018-05-22/paginators-1.json
#   inflating: /workspace/ngccli/ngc-cli/botocore/data/personalize/2018-05-22/service-2.json
#   inflating: /workspace/ngccli/ngc-cli/libpcre.so.1
#    creating: /workspace/ngccli/ngc-cli/grpc/
#    creating: /workspace/ngccli/ngc-cli/grpc/_cython/
#    creating: /workspace/ngccli/ngc-cli/grpc/_cython/_credentials/
#   inflating: /workspace/ngccli/ngc-cli/grpc/_cython/_credentials/roots.pem
#   inflating: /workspace/ngccli/ngc-cli/grpc/_cython/cygrpc.cpython-39-x86_64-linux-gnu.so
#   inflating: /workspace/ngccli/ngc-cli/libffi-9c61262e.so.8.1.0
#    creating: /workspace/ngccli/ngc-cli/boto3/
#    creating: /workspace/ngccli/ngc-cli/boto3/examples/
#   inflating: /workspace/ngccli/ngc-cli/boto3/examples/s3.rst
#   inflating: /workspace/ngccli/ngc-cli/boto3/examples/cloudfront.rst
#    creating: /workspace/ngccli/ngc-cli/boto3/data/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/iam/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/iam/2010-05-08/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/iam/2010-05-08/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/sns/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/sns/2010-03-31/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/sns/2010-03-31/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/glacier/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/glacier/2012-06-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/glacier/2012-06-01/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2014-10-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2014-10-01/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2016-11-15/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2016-11-15/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2015-03-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2015-03-01/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2015-10-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2015-10-01/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2015-04-15/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2015-04-15/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2016-04-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2016-04-01/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2016-09-15/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/ec2/2016-09-15/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/opsworks/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/opsworks/2013-02-18/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/opsworks/2013-02-18/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/cloudwatch/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/cloudwatch/2010-08-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/cloudwatch/2010-08-01/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/cloudformation/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/cloudformation/2010-05-15/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/cloudformation/2010-05-15/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/dynamodb/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/dynamodb/2012-08-10/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/dynamodb/2012-08-10/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/sqs/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/sqs/2012-11-05/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/sqs/2012-11-05/resources-1.json
#    creating: /workspace/ngccli/ngc-cli/boto3/data/s3/
#    creating: /workspace/ngccli/ngc-cli/boto3/data/s3/2006-03-01/
#   inflating: /workspace/ngccli/ngc-cli/boto3/data/s3/2006-03-01/resources-1.json
#   inflating: /workspace/ngccli/ngc-cli/libssl.so.10
#    creating: /workspace/ngccli/ngc-cli/frozenlist/
#   inflating: /workspace/ngccli/ngc-cli/frozenlist/_frozenlist.cpython-39-x86_64-linux-gnu.so
#  extracting: /workspace/ngccli/ngc-cli.md5

# %%
# !../ngccli/ngc-cli/ngc registry model list nvidia/tao/pretrained_classification:*
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | Versi | Accur | Epoch | Batch | GPU   | Memor | File  | Statu | Creat |
# | on    | acy   | s     | Size  | Model | y Foo | Size  | s     | ed    |
# |       |       |       |       |       | tprin |       |       | Date  |
# |       |       |       |       |       | t     |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | vgg19 | 77.56 | 80    | 1     | V100  | 153.7 | 153.7 | UPLOA | Aug   |
# |       |       |       |       |       |       | 2 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | vgg16 | 77.17 | 80    | 1     | V100  | 113.2 | 113.1 | UPLOA | Aug   |
# |       |       |       |       |       |       | 6 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | squee | 65.13 | 80    | 1     | V100  | 6.5   | 6.46  | UPLOA | Aug   |
# | zenet |       |       |       |       |       | MB    | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 77.91 | 80    | 1     | V100  | 294.2 | 294.2 | UPLOA | Aug   |
# | t50   |       |       |       |       |       | MB    | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 77.04 | 80    | 1     | V100  | 170.7 | 170.6 | UPLOA | Aug   |
# | t34   |       |       |       |       |       | 5 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 76.74 | 80    | 1     | V100  | 89.0  | 88.96 | UPLOA | Aug   |
# | t18   |       |       |       |       |       | MB    | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 77.78 | 80    | 1     | V100  | 576.3 | 576.3 | UPLOA | Aug   |
# | t101  |       |       |       |       |       | 3 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 74.38 | 80    | 1     | V100  | 38.3  | 38.31 | UPLOA | Aug   |
# | t10   |       |       |       |       |       | MB    | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | mobil | 72.75 | 80    | 1     | V100  | 5.0   | 5.01  | UPLOA | Aug   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 18,   |
# | v2    |       |       |       |       |       |       | PLETE | 2021  |
# | mobil | 79.5  | 80    | 1     | V100  | 26.2  | 26.22 | UPLOA | Aug   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 18,   |
# | v1    |       |       |       |       |       |       | PLETE | 2021  |
# | googl | 77.11 | 80    | 1     | V100  | 47.6  | 47.64 | UPLOA | Aug   |
# | enet  |       |       |       |       |       | MB    | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | effic | 77.11 | 80    | 1     | V100  | 26.8  | 26.78 | UPLOA | Aug   |
# | ientn |       |       |       |       |       | MB    | D_COM | 18,   |
# | et_b1 |       |       |       |       |       |       | PLETE | 2021  |
# | _swis |       |       |       |       |       |       |       |       |
# | h     |       |       |       |       |       |       |       |       |
# | effic | 77.11 | 80    | 1     | V100  | 26.8  | 26.78 | UPLOA | Aug   |
# | ientn |       |       |       |       |       | MB    | D_COM | 18,   |
# | et_b1 |       |       |       |       |       |       | PLETE | 2021  |
# | _relu |       |       |       |       |       |       |       |       |
# | darkn | 76.44 | 80    | 1     | V100  | 311.7 | 311.6 | UPLOA | Aug   |
# | et53  |       |       |       |       |       | 8 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | darkn | 77.52 | 80    | 1     | V100  | 152.8 | 152.8 | UPLOA | Aug   |
# | et19  |       |       |       |       |       | 2 MB  | D_COM | 18,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | cspda | 77.1  | 80    | 1     | V100  | 28.6  | 28.57 | UPLOA | Nov   |
# | rknet |       |       |       |       |       | MB    | D_COM | 23,   |
# | _tiny |       |       |       |       |       |       | PLETE | 2021  |
# | cspda | 76.44 | 80    | 1     | V100  | 103.0 | 102.9 | UPLOA | Sep   |
# | rknet |       |       |       |       |       | 9 MB  | D_COM | 10,   |
# | 53    |       |       |       |       |       |       | PLETE | 2021  |
# | cspda | 77.52 | 80    | 1     | V100  | 62.9  | 62.86 | UPLOA | Sep   |
# | rknet |       |       |       |       |       | MB    | D_COM | 10,   |
# | 19    |       |       |       |       |       |       | PLETE | 2021  |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
# !mkdir -p $LOCAL_EXPERIMENT_DIR/pretrained_resnet50/

# %%
# Pull pretrained model from NGC
# !../ngccli/ngc-cli/ngc registry model download-version nvidia/tao/pretrained_classification:resnet50 \
    --dest $LOCAL_EXPERIMENT_DIR/pretrained_resnet50
# Out:
# Downloaded 272.54 MB in 1m 54s, Download speed: 2.39 MB/s
# --------------------------------------------------------------------------------
#    Transfer id: pretrained_classification_vresnet50
#    Download status: Completed
#    Downloaded local path: /workspace/faceclassification/pretrained_resnet50/pretrained_classification_vresnet50
#    Total files downloaded: 1
#    Total downloaded size: 272.54 MB
#    Started at: 2022-08-09 07:06:40.436218
#    Completed at: 2022-08-09 07:08:34.611480
#    Duration taken: 1m 54s
# --------------------------------------------------------------------------------

# %% [markdown]
# ### TRAINING

# %% [markdown]
# #### 2.1 Creating config file for training

# %%
# !cat $LOCAL_SPECS_DIR/classification_mobilenet.cfg
# Out:
# model_config {
#   arch: "resnet",
#   n_layers: 18
#   # Setting these parameters to true to match the template downloaded from NGC.
#   use_batch_norm: true
#   all_projections: true
#   freeze_blocks: 0
#   freeze_blocks: 1
#   input_image_size: "3,224,224"
# }
# train_config {
#   train_dataset_path: "/workspace/tao-experiments/data/split/train"
#   val_dataset_path: "/workspace/tao-experiments/data/split/val"
#   pretrained_model_path: "/workspace/tao-experiments/classification/pretrained_resnet18/pretrained_classification_vresnet18/resnet_18.hdf5"
#   optimizer {
#     sgd {
#     lr: 0.01
#     decay: 0.0
#     momentum: 0.9
#     nesterov: False
#   }
# }
#   batch_size_per_gpu: 64
#   n_epochs: 80
#   n_workers: 16
#   preprocess_mode: "caffe"
#   enable_random_crop: True
#   enable_center_crop: True
#   label_smoothing: 0.0
#   mixup_alpha: 0.1
#   # regularizer
#   reg_config {
#     type: "L2"
#     scope: "Conv2D,Dense"
#     weight_decay: 0.00005
#   }
#
#   # learning_rate
#   lr_config {
#     step {
#       learning_rate: 0.006
#       step_size: 10
#       gamma: 0.1
#     }
#   }
# }
# eval_config {
#   eval_dataset_path: "/workspace/tao-experiments/data/split/test"
#   model_path: "/workspace/tao-experiments/classification/output/weights/resnet_080.tlt"
#   top_k: 3
#   batch_size: 256
#   n_workers: 8
#   enable_center_crop: True
# }

# %% [markdown]
# #### 2.1 Train the mpre-trained model

# %%
# !tao classification train -e $SPECS_DIR/classification_spec.cfg -r $USER_EXPERIMENT_DIR/output -k $KEY
# Out:
# 2022-08-09 07:32:21,612 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 07:32:21,765 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2022-08-09 07:32:31,005 [INFO] __main__: Loading experiment spec at /workspace/faceclassification/specs/classification_spec.cfg.
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:384: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-08-09 07:32:31,015 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:384: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:393: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-08-09 07:32:31,016 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:393: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-08-09 07:32:31,698 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/output/status.json
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2022-08-09 07:32:31,698 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-08-09 07:32:31,699 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-08-09 07:32:31,699 [INFO] __main__: Default image mean [103.939, 116.779, 123.68] will be used.
# Found 1465 images belonging to 3 classes.
# 2022-08-09 07:32:31,810 [INFO] __main__: Processing dataset (train): /workspace/data/train
# Found 203 images belonging to 3 classes.
# 2022-08-09 07:32:31,915 [INFO] __main__: Processing dataset (validation): /workspace/data/val
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2022-08-09 07:32:31,916 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2022-08-09 07:32:31,917 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2022-08-09 07:32:31,923 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2022-08-09 07:32:31,948 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2022-08-09 07:32:31,955 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2022-08-09 07:32:34,119 [WARNING] tensorflow: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2022-08-09 07:32:36,532 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2022-08-09 07:32:36,532 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2022-08-09 07:32:36,533 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2022-08-09 07:32:38,083 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 224, 224)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 112, 112) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 112, 112) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 112, 112) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 56, 56)   4096        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 56, 56)   256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 56, 56)   0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 56, 56)   36864       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 56, 56)   256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_2 (Activation)    (None, 64, 56, 56)   0           block_1a_bn_2[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_3 (Conv2D)        (None, 256, 56, 56)  16384       block_1a_relu_2[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 256, 56, 56)  16384       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_3 (BatchNormalizati (None, 256, 56, 56)  1024        block_1a_conv_3[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 256, 56, 56)  1024        block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 56, 56)  0           block_1a_bn_3[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 256, 56, 56)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 56, 56)   16384       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (None, 64, 56, 56)   256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 56, 56)   0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 56, 56)   36864       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (None, 64, 56, 56)   256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_2 (Activation)    (None, 64, 56, 56)   0           block_1b_bn_2[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_3 (Conv2D)        (None, 256, 56, 56)  16384       block_1b_relu_2[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 256, 56, 56)  65536       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_3 (BatchNormalizati (None, 256, 56, 56)  1024        block_1b_conv_3[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_shortcut (BatchNorm (None, 256, 56, 56)  1024        block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 56, 56)  0           block_1b_bn_3[0][0]
#                                                                  block_1b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 256, 56, 56)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block_1c_conv_1 (Conv2D)        (None, 64, 56, 56)   16384       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_1c_bn_1 (BatchNormalizati (None, 64, 56, 56)   256         block_1c_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1c_relu_1 (Activation)    (None, 64, 56, 56)   0           block_1c_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1c_conv_2 (Conv2D)        (None, 64, 56, 56)   36864       block_1c_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1c_bn_2 (BatchNormalizati (None, 64, 56, 56)   256         block_1c_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1c_relu_2 (Activation)    (None, 64, 56, 56)   0           block_1c_bn_2[0][0]
# __________________________________________________________________________________________________
# block_1c_conv_3 (Conv2D)        (None, 256, 56, 56)  16384       block_1c_relu_2[0][0]
# __________________________________________________________________________________________________
# block_1c_conv_shortcut (Conv2D) (None, 256, 56, 56)  65536       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_1c_bn_3 (BatchNormalizati (None, 256, 56, 56)  1024        block_1c_conv_3[0][0]
# __________________________________________________________________________________________________
# block_1c_bn_shortcut (BatchNorm (None, 256, 56, 56)  1024        block_1c_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256, 56, 56)  0           block_1c_bn_3[0][0]
#                                                                  block_1c_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1c_relu (Activation)      (None, 256, 56, 56)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 28, 28)  32768       block_1c_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 28, 28)  512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 28, 28)  0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 28, 28)  147456      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 28, 28)  512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_2 (Activation)    (None, 128, 28, 28)  0           block_2a_bn_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_3 (Conv2D)        (None, 512, 28, 28)  65536       block_2a_relu_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 512, 28, 28)  131072      block_1c_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_3 (BatchNormalizati (None, 512, 28, 28)  2048        block_2a_conv_3[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 512, 28, 28)  2048        block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 512, 28, 28)  0           block_2a_bn_3[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 512, 28, 28)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 28, 28)  65536       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (None, 128, 28, 28)  512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 28, 28)  0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 28, 28)  147456      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (None, 128, 28, 28)  512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_2 (Activation)    (None, 128, 28, 28)  0           block_2b_bn_2[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_3 (Conv2D)        (None, 512, 28, 28)  65536       block_2b_relu_2[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 512, 28, 28)  262144      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_3 (BatchNormalizati (None, 512, 28, 28)  2048        block_2b_conv_3[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_shortcut (BatchNorm (None, 512, 28, 28)  2048        block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 512, 28, 28)  0           block_2b_bn_3[0][0]
#                                                                  block_2b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 512, 28, 28)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_2c_conv_1 (Conv2D)        (None, 128, 28, 28)  65536       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_2c_bn_1 (BatchNormalizati (None, 128, 28, 28)  512         block_2c_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2c_relu_1 (Activation)    (None, 128, 28, 28)  0           block_2c_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2c_conv_2 (Conv2D)        (None, 128, 28, 28)  147456      block_2c_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2c_bn_2 (BatchNormalizati (None, 128, 28, 28)  512         block_2c_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2c_relu_2 (Activation)    (None, 128, 28, 28)  0           block_2c_bn_2[0][0]
# __________________________________________________________________________________________________
# block_2c_conv_3 (Conv2D)        (None, 512, 28, 28)  65536       block_2c_relu_2[0][0]
# __________________________________________________________________________________________________
# block_2c_conv_shortcut (Conv2D) (None, 512, 28, 28)  262144      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_2c_bn_3 (BatchNormalizati (None, 512, 28, 28)  2048        block_2c_conv_3[0][0]
# __________________________________________________________________________________________________
# block_2c_bn_shortcut (BatchNorm (None, 512, 28, 28)  2048        block_2c_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 512, 28, 28)  0           block_2c_bn_3[0][0]
#                                                                  block_2c_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2c_relu (Activation)      (None, 512, 28, 28)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_2d_conv_1 (Conv2D)        (None, 128, 28, 28)  65536       block_2c_relu[0][0]
# __________________________________________________________________________________________________
# block_2d_bn_1 (BatchNormalizati (None, 128, 28, 28)  512         block_2d_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2d_relu_1 (Activation)    (None, 128, 28, 28)  0           block_2d_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2d_conv_2 (Conv2D)        (None, 128, 28, 28)  147456      block_2d_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2d_bn_2 (BatchNormalizati (None, 128, 28, 28)  512         block_2d_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2d_relu_2 (Activation)    (None, 128, 28, 28)  0           block_2d_bn_2[0][0]
# __________________________________________________________________________________________________
# block_2d_conv_3 (Conv2D)        (None, 512, 28, 28)  65536       block_2d_relu_2[0][0]
# __________________________________________________________________________________________________
# block_2d_conv_shortcut (Conv2D) (None, 512, 28, 28)  262144      block_2c_relu[0][0]
# __________________________________________________________________________________________________
# block_2d_bn_3 (BatchNormalizati (None, 512, 28, 28)  2048        block_2d_conv_3[0][0]
# __________________________________________________________________________________________________
# block_2d_bn_shortcut (BatchNorm (None, 512, 28, 28)  2048        block_2d_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 28, 28)  0           block_2d_bn_3[0][0]
#                                                                  block_2d_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2d_relu (Activation)      (None, 512, 28, 28)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 14, 14)  131072      block_2d_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 256, 14, 14)  1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 14, 14)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 14, 14)  589824      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 256, 14, 14)  1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_2 (Activation)    (None, 256, 14, 14)  0           block_3a_bn_2[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_3 (Conv2D)        (None, 1024, 14, 14) 262144      block_3a_relu_2[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 1024, 14, 14) 524288      block_2d_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_3 (BatchNormalizati (None, 1024, 14, 14) 4096        block_3a_conv_3[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 1024, 14, 14) 4096        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1024, 14, 14) 0           block_3a_bn_3[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 1024, 14, 14) 0           add_8[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 14, 14)  262144      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (None, 256, 14, 14)  1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 14, 14)  0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 14, 14)  589824      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (None, 256, 14, 14)  1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_2 (Activation)    (None, 256, 14, 14)  0           block_3b_bn_2[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_3 (Conv2D)        (None, 1024, 14, 14) 262144      block_3b_relu_2[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 1024, 14, 14) 1048576     block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_3 (BatchNormalizati (None, 1024, 14, 14) 4096        block_3b_conv_3[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_shortcut (BatchNorm (None, 1024, 14, 14) 4096        block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 1024, 14, 14) 0           block_3b_bn_3[0][0]
#                                                                  block_3b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 1024, 14, 14) 0           add_9[0][0]
# __________________________________________________________________________________________________
# block_3c_conv_1 (Conv2D)        (None, 256, 14, 14)  262144      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_3c_bn_1 (BatchNormalizati (None, 256, 14, 14)  1024        block_3c_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3c_relu_1 (Activation)    (None, 256, 14, 14)  0           block_3c_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3c_conv_2 (Conv2D)        (None, 256, 14, 14)  589824      block_3c_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3c_bn_2 (BatchNormalizati (None, 256, 14, 14)  1024        block_3c_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3c_relu_2 (Activation)    (None, 256, 14, 14)  0           block_3c_bn_2[0][0]
# __________________________________________________________________________________________________
# block_3c_conv_3 (Conv2D)        (None, 1024, 14, 14) 262144      block_3c_relu_2[0][0]
# __________________________________________________________________________________________________
# block_3c_conv_shortcut (Conv2D) (None, 1024, 14, 14) 1048576     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_3c_bn_3 (BatchNormalizati (None, 1024, 14, 14) 4096        block_3c_conv_3[0][0]
# __________________________________________________________________________________________________
# block_3c_bn_shortcut (BatchNorm (None, 1024, 14, 14) 4096        block_3c_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 1024, 14, 14) 0           block_3c_bn_3[0][0]
#                                                                  block_3c_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3c_relu (Activation)      (None, 1024, 14, 14) 0           add_10[0][0]
# __________________________________________________________________________________________________
# block_3d_conv_1 (Conv2D)        (None, 256, 14, 14)  262144      block_3c_relu[0][0]
# __________________________________________________________________________________________________
# block_3d_bn_1 (BatchNormalizati (None, 256, 14, 14)  1024        block_3d_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3d_relu_1 (Activation)    (None, 256, 14, 14)  0           block_3d_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3d_conv_2 (Conv2D)        (None, 256, 14, 14)  589824      block_3d_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3d_bn_2 (BatchNormalizati (None, 256, 14, 14)  1024        block_3d_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3d_relu_2 (Activation)    (None, 256, 14, 14)  0           block_3d_bn_2[0][0]
# __________________________________________________________________________________________________
# block_3d_conv_3 (Conv2D)        (None, 1024, 14, 14) 262144      block_3d_relu_2[0][0]
# __________________________________________________________________________________________________
# block_3d_conv_shortcut (Conv2D) (None, 1024, 14, 14) 1048576     block_3c_relu[0][0]
# __________________________________________________________________________________________________
# block_3d_bn_3 (BatchNormalizati (None, 1024, 14, 14) 4096        block_3d_conv_3[0][0]
# __________________________________________________________________________________________________
# block_3d_bn_shortcut (BatchNorm (None, 1024, 14, 14) 4096        block_3d_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 1024, 14, 14) 0           block_3d_bn_3[0][0]
#                                                                  block_3d_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3d_relu (Activation)      (None, 1024, 14, 14) 0           add_11[0][0]
# __________________________________________________________________________________________________
# block_3e_conv_1 (Conv2D)        (None, 256, 14, 14)  262144      block_3d_relu[0][0]
# __________________________________________________________________________________________________
# block_3e_bn_1 (BatchNormalizati (None, 256, 14, 14)  1024        block_3e_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3e_relu_1 (Activation)    (None, 256, 14, 14)  0           block_3e_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3e_conv_2 (Conv2D)        (None, 256, 14, 14)  589824      block_3e_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3e_bn_2 (BatchNormalizati (None, 256, 14, 14)  1024        block_3e_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3e_relu_2 (Activation)    (None, 256, 14, 14)  0           block_3e_bn_2[0][0]
# __________________________________________________________________________________________________
# block_3e_conv_3 (Conv2D)        (None, 1024, 14, 14) 262144      block_3e_relu_2[0][0]
# __________________________________________________________________________________________________
# block_3e_conv_shortcut (Conv2D) (None, 1024, 14, 14) 1048576     block_3d_relu[0][0]
# __________________________________________________________________________________________________
# block_3e_bn_3 (BatchNormalizati (None, 1024, 14, 14) 4096        block_3e_conv_3[0][0]
# __________________________________________________________________________________________________
# block_3e_bn_shortcut (BatchNorm (None, 1024, 14, 14) 4096        block_3e_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 1024, 14, 14) 0           block_3e_bn_3[0][0]
#                                                                  block_3e_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3e_relu (Activation)      (None, 1024, 14, 14) 0           add_12[0][0]
# __________________________________________________________________________________________________
# block_3f_conv_1 (Conv2D)        (None, 256, 14, 14)  262144      block_3e_relu[0][0]
# __________________________________________________________________________________________________
# block_3f_bn_1 (BatchNormalizati (None, 256, 14, 14)  1024        block_3f_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3f_relu_1 (Activation)    (None, 256, 14, 14)  0           block_3f_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3f_conv_2 (Conv2D)        (None, 256, 14, 14)  589824      block_3f_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3f_bn_2 (BatchNormalizati (None, 256, 14, 14)  1024        block_3f_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3f_relu_2 (Activation)    (None, 256, 14, 14)  0           block_3f_bn_2[0][0]
# __________________________________________________________________________________________________
# block_3f_conv_3 (Conv2D)        (None, 1024, 14, 14) 262144      block_3f_relu_2[0][0]
# __________________________________________________________________________________________________
# block_3f_conv_shortcut (Conv2D) (None, 1024, 14, 14) 1048576     block_3e_relu[0][0]
# __________________________________________________________________________________________________
# block_3f_bn_3 (BatchNormalizati (None, 1024, 14, 14) 4096        block_3f_conv_3[0][0]
# __________________________________________________________________________________________________
# block_3f_bn_shortcut (BatchNorm (None, 1024, 14, 14) 4096        block_3f_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 1024, 14, 14) 0           block_3f_bn_3[0][0]
#                                                                  block_3f_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3f_relu (Activation)      (None, 1024, 14, 14) 0           add_13[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 14, 14)  524288      block_3f_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 512, 14, 14)  2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 14, 14)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 14, 14)  2359296     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 512, 14, 14)  2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_2 (Activation)    (None, 512, 14, 14)  0           block_4a_bn_2[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_3 (Conv2D)        (None, 2048, 14, 14) 1048576     block_4a_relu_2[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 2048, 14, 14) 2097152     block_3f_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_3 (BatchNormalizati (None, 2048, 14, 14) 8192        block_4a_conv_3[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 2048, 14, 14) 8192        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2048, 14, 14) 0           block_4a_bn_3[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 2048, 14, 14) 0           add_14[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 14, 14)  1048576     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (None, 512, 14, 14)  2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 14, 14)  0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 14, 14)  2359296     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (None, 512, 14, 14)  2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_2 (Activation)    (None, 512, 14, 14)  0           block_4b_bn_2[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_3 (Conv2D)        (None, 2048, 14, 14) 1048576     block_4b_relu_2[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 2048, 14, 14) 4194304     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_3 (BatchNormalizati (None, 2048, 14, 14) 8192        block_4b_conv_3[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_shortcut (BatchNorm (None, 2048, 14, 14) 8192        block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2048, 14, 14) 0           block_4b_bn_3[0][0]
#                                                                  block_4b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 2048, 14, 14) 0           add_15[0][0]
# __________________________________________________________________________________________________
# block_4c_conv_1 (Conv2D)        (None, 512, 14, 14)  1048576     block_4b_relu[0][0]
# __________________________________________________________________________________________________
# block_4c_bn_1 (BatchNormalizati (None, 512, 14, 14)  2048        block_4c_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4c_relu_1 (Activation)    (None, 512, 14, 14)  0           block_4c_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4c_conv_2 (Conv2D)        (None, 512, 14, 14)  2359296     block_4c_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4c_bn_2 (BatchNormalizati (None, 512, 14, 14)  2048        block_4c_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4c_relu_2 (Activation)    (None, 512, 14, 14)  0           block_4c_bn_2[0][0]
# __________________________________________________________________________________________________
# block_4c_conv_3 (Conv2D)        (None, 2048, 14, 14) 1048576     block_4c_relu_2[0][0]
# __________________________________________________________________________________________________
# block_4c_conv_shortcut (Conv2D) (None, 2048, 14, 14) 4194304     block_4b_relu[0][0]
# __________________________________________________________________________________________________
# block_4c_bn_3 (BatchNormalizati (None, 2048, 14, 14) 8192        block_4c_conv_3[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 2022-08-09 07:34:38,972 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# 2022-08-09 07:34:38,985 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1123: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-08-09 07:34:39,020 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1123: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-08-09 07:34:39,021 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/output/status.json
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# 2022-08-09 07:34:43,333 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2022-08-09 07:34:43,777 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 2022-08-09 07:34:47,514 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 2022-08-09 07:34:50,230 [INFO] root: Starting Training Loop.
# Epoch 1/80
#  1/23 [>.............................] - ETA: 10:50 - loss: 1.4278 - acc: 0.3594WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:186: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# 2022-08-09 07:35:25,465 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:186: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
#  2/23 [=>............................] - ETA: 6:22 - loss: 1.3538 - acc: 0.4375 /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (3.111312). Check your callbacks.
#   % delta_t_median)
# 23/23 [==============================] - 69s 3s/step - loss: 0.6856 - acc: 0.8940 - val_loss: 0.2603 - val_acc: 1.0000
# f484223acae1:77:108 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.4<0>
# f484223acae1:77:108 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# f484223acae1:77:108 [0] NCCL INFO P2P plugin IBext
# f484223acae1:77:108 [0] NCCL INFO NET/IB : No device found.
# f484223acae1:77:108 [0] NCCL INFO NET/IB : No device found.
# f484223acae1:77:108 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.4<0>
# f484223acae1:77:108 [0] NCCL INFO Using network Socket
# NCCL version 2.11.4+cuda11.6
# f484223acae1:77:108 [0] NCCL INFO Channel 00/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 01/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 02/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 03/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 04/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 05/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 06/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 07/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 08/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 09/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 10/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 11/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 12/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 13/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 14/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 15/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 16/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 17/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 18/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 19/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 20/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 21/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 22/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 23/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 24/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 25/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 26/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 27/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 28/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 29/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 30/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Channel 31/32 :    0
# f484223acae1:77:108 [0] NCCL INFO Trees [0] -1/-1/-1->0->-1 [1] -1/-1/-1->0->-1 [2] -1/-1/-1->0->-1 [3] -1/-1/-1->0->-1 [4] -1/-1/-1->0->-1 [5] -1/-1/-1->0->-1 [6] -1/-1/-1->0->-1 [7] -1/-1/-1->0->-1 [8] -1/-1/-1->0->-1 [9] -1/-1/-1->0->-1 [10] -1/-1/-1->0->-1 [11] -1/-1/-1->0->-1 [12] -1/-1/-1->0->-1 [13] -1/-1/-1->0->-1 [14] -1/-1/-1->0->-1 [15] -1/-1/-1->0->-1 [16] -1/-1/-1->0->-1 [17] -1/-1/-1->0->-1 [18] -1/-1/-1->0->-1 [19] -1/-1/-1->0->-1 [20] -1/-1/-1->0->-1 [21] -1/-1/-1->0->-1 [22] -1/-1/-1->0->-1 [23] -1/-1/-1->0->-1 [24] -1/-1/-1->0->-1 [25] -1/-1/-1->0->-1 [26] -1/-1/-1->0->-1 [27] -1/-1/-1->0->-1 [28] -1/-1/-1->0->-1 [29] -1/-1/-1->0->-1 [30] -1/-1/-1->0->-1 [31] -1/-1/-1->0->-1
# f484223acae1:77:108 [0] NCCL INFO Connected all rings
# f484223acae1:77:108 [0] NCCL INFO Connected all trees
# f484223acae1:77:108 [0] NCCL INFO 32 coll channels, 32 p2p channels, 32 p2p channels per peer
# f484223acae1:77:108 [0] NCCL INFO comm 0x7fcb58431180 rank 0 nranks 1 cudaDev 0 busId 3000 - Init COMPLETE
# 2022-08-09 07:36:20,744 [INFO] root: Unable to flush file's cached information (file write failed: time = Tue Aug  9 07:36:20 2022
# , filename = '/tmp/tmpn_l90r0u', file descriptor = 52, errno = 28, error message = 'No space left on device', buf = 0x480406a0, total write size = 2048, bytes this sub-write = 2048, bytes actually written = 18446744073709551615, offset = 4096)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/saving.py", line 382, in save_model
#     _serialize_model(model, f, include_optimizer)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/saving.py", line 171, in _serialize_model
#     optimizer_weights_group[name] = val
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py", line 223, in __setitem__
#     dataset[:] = val
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/dataset.py", line 632, in __setitem__
#     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5d.pyx", line 221, in h5py.h5d.DatasetID.write
#   File "h5py/_proxy.pyx", line 132, in h5py._proxy.dset_rw
#   File "h5py/_proxy.pyx", line 93, in h5py._proxy.H5PY_H5Dwrite
# OSError: Can't prepare for writing data (file write failed: time = Tue Aug  9 07:36:20 2022
# , filename = '/tmp/tmpn_l90r0u', file descriptor = 52, errno = 28, error message = 'No space left on device', buf = 0x7fca1cc9b5c0, total write size = 10410560, bytes this sub-write = 10410560, bytes actually written = 18446744073709551615, offset = 293765120)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py", line 653, in <module>
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py", line 707, in return_func
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py", line 695, in return_func
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py", line 649, in main
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py", line 635, in main
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py", line 600, in run_experiment
#   File "/usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training.py", line 1418, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py", line 251, in fit_generator
#     callbacks.on_epoch_end(epoch, epoch_logs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/callbacks.py", line 79, in on_epoch_end
#     callback.on_epoch_end(epoch, logs)
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/utils/callbacks.py", line 62, in on_epoch_end
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py", line 353, in encode_from_keras
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/network.py", line 1090, in save
#     save_model(self, filepath, overwrite, include_optimizer)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/saving.py", line 385, in save_model
#     f.close()
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py", line 330, in close
#     self.data.file.flush()
#   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 351, in flush
#     h5f.flush(self.fid)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 115, in h5py.h5f.flush
# RuntimeError: Unable to flush file's cached information (file write failed: time = Tue Aug  9 07:36:20 2022
# , filename = '/tmp/tmpn_l90r0u', file descriptor = 52, errno = 28, error message = 'No space left on device', buf = 0x480406a0, total write size = 2048, bytes this sub-write = 2048, bytes actually written = 18446744073709551615, offset = 4096)
# Traceback (most recent call last):
#   File "h5py/_objects.pyx", line 193, in h5py._objects.ObjectID.__dealloc__
# RuntimeError: Problems closing file (file write failed: time = Tue Aug  9 07:36:21 2022
# , filename = '/tmp/tmpn_l90r0u', file descriptor = 52, errno = 28, error message = 'No space left on device', buf = 0x345656f0, total write size = 91432, bytes this sub-write = 91432, bytes actually written = 18446744073709551615, offset = 16384)
# Exception ignored in: 'h5py._objects.ObjectID.__dealloc__'
# Traceback (most recent call last):
#   File "h5py/_objects.pyx", line 193, in h5py._objects.ObjectID.__dealloc__
# RuntimeError: Problems closing file (file write failed: time = Tue Aug  9 07:36:21 2022
# , filename = '/tmp/tmpn_l90r0u', file descriptor = 52, errno = 28, error message = 'No space left on device', buf = 0x345656f0, total write size = 91432, bytes this sub-write = 91432, bytes actually written = 18446744073709551615, offset = 16384)
# [f484223acae1:77   :0:77] Caught signal 11 (Segmentation fault: address not mapped to object at address 0x558)
# ==== backtrace (tid:     77) ====
#  0 0x00000000000153c0 __funlockfile()  ???:0
#  1 0x00000000000f60e4 H5F_close()  ???:0
#  2 0x0000000000177931 H5HP_close()  ???:0
#  3 0x0000000000245abe H5SL_try_free_safe()  ???:0
#  4 0x00000000001782ac H5I_clear_type()  ???:0
#  5 0x00000000000ec94c H5F_term_package()  ???:0
#  6 0x0000000000045a79 ???()  /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0:0
#  7 0x0000000000049a27 __libc_secure_getenv()  ???:0
#  8 0x0000000000049be0 exit()  ???:0
#  9 0x00000000000270ba __libc_start_main()  ???:0
# 10 0x00000000005bc64e _start()  ???:0
# =================================
# [f484223acae1:00077] *** Process received signal ***
# [f484223acae1:00077] Signal: Segmentation fault (11)
# [f484223acae1:00077] Signal code:  (-6)
# [f484223acae1:00077] Failing at address: 0x4d
# [f484223acae1:00077] [ 0] /usr/lib/x86_64-linux-gnu/libpthread.so.0(+0x153c0)[0x7fcc0e27d3c0]
# [f484223acae1:00077] [ 1] /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0(H5F_close+0x24)[0x7fcb93f900e4]
# [f484223acae1:00077] [ 2] /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0(+0x177931)[0x7fcb94011931]
# [f484223acae1:00077] [ 3] /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0(H5SL_try_free_safe+0x6e)[0x7fcb940dfabe]
# [f484223acae1:00077] [ 4] /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0(H5I_clear_type+0x7c)[0x7fcb940122ac]
# [f484223acae1:00077] [ 5] /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0(H5F_term_package+0x2c)[0x7fcb93f8694c]
# [f484223acae1:00077] [ 6] /usr/local/lib/python3.6/dist-packages/h5py/.libs/libhdf5-907b7611.so.101.1.0(+0x45a79)[0x7fcb93edfa79]
# [f484223acae1:00077] [ 7] /usr/lib/x86_64-linux-gnu/libc.so.6(+0x49a27)[0x7fcc0e2d4a27]
# [f484223acae1:00077] [ 8] /usr/lib/x86_64-linux-gnu/libc.so.6(on_exit+0x0)[0x7fcc0e2d4be0]
# [f484223acae1:00077] [ 9] /usr/lib/x86_64-linux-gnu/libc.so.6(__libc_start_main+0xfa)[0x7fcc0e2b20ba]
# [f484223acae1:00077] [10] python3.6(_start+0x2e)[0x5bc64e]
# [f484223acae1:00077] *** End of error message ***
# 2022-08-09 07:36:23,772 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao classification train -e $SPECS_DIR/classification_mobilenet.cfg -r $USER_EXPERIMENT_DIR/output -k $KEY
# Out:
# 2022-08-09 04:31:38,292 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 04:31:38,451 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2022-08-09 04:31:48,265 [INFO] __main__: Loading experiment spec at /workspace/faceclassification/specs/classification_mobilenet.cfg.
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:384: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-08-09 04:31:48,277 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:384: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:393: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-08-09 04:31:48,278 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:393: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-08-09 04:31:48,963 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/output/status.json
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2022-08-09 04:31:48,964 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-08-09 04:31:48,964 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-08-09 04:31:48,964 [INFO] __main__: Default image mean [103.939, 116.779, 123.68] will be used.
# Found 1465 images belonging to 3 classes.
# 2022-08-09 04:31:49,077 [INFO] __main__: Processing dataset (train): /workspace/data/train
# Found 203 images belonging to 3 classes.
# 2022-08-09 04:31:49,182 [INFO] __main__: Processing dataset (validation): /workspace/data/val
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2022-08-09 04:31:49,183 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2022-08-09 04:31:49,184 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2022-08-09 04:31:49,197 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2022-08-09 04:31:49,215 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2022-08-09 04:31:49,223 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2022-08-09 04:31:50,189 [WARNING] tensorflow: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2022-08-09 04:31:51,101 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2022-08-09 04:31:51,101 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2022-08-09 04:31:51,101 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2022-08-09 04:31:51,712 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 224, 224)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 3, 226, 226)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 112, 112)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 112, 112)      128
# _________________________________________________________________
# conv_block_relu (ReLU)       (None, 32, 112, 112)      0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, 32, 114, 114)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 112, 112)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 112, 112)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 112, 112)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 64, 112, 112)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 64, 112, 112)      256
# _________________________________________________________________
# conv_pw_relu_1 (ReLU)        (None, 64, 112, 112)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 64, 114, 114)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 64, 56, 56)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 64, 56, 56)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 64, 56, 56)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 128, 56, 56)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 128, 56, 56)       512
# _________________________________________________________________
# conv_pw_relu_2 (ReLU)        (None, 128, 56, 56)       0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, 128, 58, 58)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 128, 56, 56)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 128, 56, 56)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 128, 56, 56)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 128, 56, 56)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 128, 56, 56)       512
# _________________________________________________________________
# conv_pw_relu_3 (ReLU)        (None, 128, 56, 56)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 128, 58, 58)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 128, 28, 28)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 128, 28, 28)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 128, 28, 28)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 256, 28, 28)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 256, 28, 28)       1024
# _________________________________________________________________
# conv_pw_relu_4 (ReLU)        (None, 256, 28, 28)       0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, 256, 30, 30)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 256, 28, 28)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 256, 28, 28)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 256, 28, 28)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 256, 28, 28)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 256, 28, 28)       1024
# _________________________________________________________________
# conv_pw_relu_5 (ReLU)        (None, 256, 28, 28)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 256, 30, 30)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 256, 14, 14)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 256, 14, 14)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 256, 14, 14)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 512, 14, 14)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_6 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_7 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_8 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_9 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_10 (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_11 (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 512, 7, 7)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 512, 7, 7)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 512, 7, 7)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 1024, 7, 7)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_pw_relu_12 (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, 1024, 9, 9)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 1024, 7, 7)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 1024, 7, 7)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_pw_relu_13 (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1024, 1, 1)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# predictions (Dense)          (None, 3)                 3075
# =================================================================
# Total params: 3,231,939
# Trainable params: 3,206,851
# Non-trainable params: 25,088
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 2022-08-09 04:32:14,130 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# 2022-08-09 04:32:14,143 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1123: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-08-09 04:32:14,160 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1123: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-08-09 04:32:14,161 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/output/status.json
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# 2022-08-09 04:32:15,842 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2022-08-09 04:32:16,040 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 2022-08-09 04:32:17,449 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 2022-08-09 04:32:18,575 [INFO] root: Starting Training Loop.
# Epoch 1/80
#  1/23 [>.............................] - ETA: 4:23 - loss: 1.6862 - acc: 0.4219WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:186: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# 2022-08-09 04:32:32,831 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:186: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
#  2/23 [=>............................] - ETA: 2:33 - loss: 1.4753 - acc: 0.4375/usr/local/lib/python3.6/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.240373). Check your callbacks.
#   % delta_t_median)
# 23/23 [==============================] - 25s 1s/step - loss: 0.6406 - acc: 0.8707 - val_loss: 0.2161 - val_acc: 1.0000
# 4c4b966dacfb:77:108 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.4<0>
# 4c4b966dacfb:77:108 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# 4c4b966dacfb:77:108 [0] NCCL INFO P2P plugin IBext
# 4c4b966dacfb:77:108 [0] NCCL INFO NET/IB : No device found.
# 4c4b966dacfb:77:108 [0] NCCL INFO NET/IB : No device found.
# 4c4b966dacfb:77:108 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.4<0>
# 4c4b966dacfb:77:108 [0] NCCL INFO Using network Socket
# NCCL version 2.11.4+cuda11.6
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 00/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 01/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 02/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 03/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 04/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 05/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 06/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 07/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 08/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 09/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 10/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 11/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 12/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 13/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 14/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 15/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 16/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 17/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 18/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 19/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 20/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 21/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 22/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 23/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 24/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 25/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 26/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 27/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 28/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 29/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 30/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Channel 31/32 :    0
# 4c4b966dacfb:77:108 [0] NCCL INFO Trees [0] -1/-1/-1->0->-1 [1] -1/-1/-1->0->-1 [2] -1/-1/-1->0->-1 [3] -1/-1/-1->0->-1 [4] -1/-1/-1->0->-1 [5] -1/-1/-1->0->-1 [6] -1/-1/-1->0->-1 [7] -1/-1/-1->0->-1 [8] -1/-1/-1->0->-1 [9] -1/-1/-1->0->-1 [10] -1/-1/-1->0->-1 [11] -1/-1/-1->0->-1 [12] -1/-1/-1->0->-1 [13] -1/-1/-1->0->-1 [14] -1/-1/-1->0->-1 [15] -1/-1/-1->0->-1 [16] -1/-1/-1->0->-1 [17] -1/-1/-1->0->-1 [18] -1/-1/-1->0->-1 [19] -1/-1/-1->0->-1 [20] -1/-1/-1->0->-1 [21] -1/-1/-1->0->-1 [22] -1/-1/-1->0->-1 [23] -1/-1/-1->0->-1 [24] -1/-1/-1->0->-1 [25] -1/-1/-1->0->-1 [26] -1/-1/-1->0->-1 [27] -1/-1/-1->0->-1 [28] -1/-1/-1->0->-1 [29] -1/-1/-1->0->-1 [30] -1/-1/-1->0->-1 [31] -1/-1/-1->0->-1
# 4c4b966dacfb:77:108 [0] NCCL INFO Connected all rings
# 4c4b966dacfb:77:108 [0] NCCL INFO Connected all trees
# 4c4b966dacfb:77:108 [0] NCCL INFO 32 coll channels, 32 p2p channels, 32 p2p channels per peer
# 4c4b966dacfb:77:108 [0] NCCL INFO comm 0x7f0e8434f380 rank 0 nranks 1 cudaDev 0 busId 3000 - Init COMPLETE
# 2022-08-09 04:32:51,402 [INFO] root: Training loop in progress
# Epoch 2/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.4166 - acc: 0.9809 - val_loss: 0.2165 - val_acc: 1.0000
# 2022-08-09 04:33:00,797 [INFO] root: Training loop in progress
# Epoch 3/80
# 23/23 [==============================] - 5s 221ms/step - loss: 0.4092 - acc: 0.9815 - val_loss: 0.2183 - val_acc: 1.0000
# 2022-08-09 04:33:06,947 [INFO] root: Training loop in progress
# Epoch 4/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3791 - acc: 0.9890 - val_loss: 0.2209 - val_acc: 1.0000
# 2022-08-09 04:33:12,538 [INFO] root: Training loop in progress
# Epoch 5/80
# 23/23 [==============================] - 5s 221ms/step - loss: 0.3799 - acc: 0.9851 - val_loss: 0.2219 - val_acc: 1.0000
# 2022-08-09 04:33:18,188 [INFO] root: Training loop in progress
# Epoch 6/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3657 - acc: 0.9842 - val_loss: 0.2218 - val_acc: 1.0000
# 2022-08-09 04:33:23,807 [INFO] root: Training loop in progress
# Epoch 7/80
# 23/23 [==============================] - 5s 215ms/step - loss: 0.3609 - acc: 0.9884 - val_loss: 0.2224 - val_acc: 1.0000
# 2022-08-09 04:33:29,363 [INFO] root: Training loop in progress
# Epoch 8/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3576 - acc: 0.9829 - val_loss: 0.2224 - val_acc: 1.0000
# 2022-08-09 04:33:34,961 [INFO] root: Training loop in progress
# Epoch 9/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3653 - acc: 0.9857 - val_loss: 0.2227 - val_acc: 1.0000
# 2022-08-09 04:33:40,544 [INFO] root: Training loop in progress
# Epoch 10/80
# 23/23 [==============================] - 5s 216ms/step - loss: 0.3657 - acc: 0.9871 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:33:46,144 [INFO] root: Training loop in progress
# Epoch 11/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3721 - acc: 0.9878 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:33:51,785 [INFO] root: Training loop in progress
# Epoch 12/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3724 - acc: 0.9878 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:33:57,441 [INFO] root: Training loop in progress
# Epoch 13/80
# 23/23 [==============================] - 5s 216ms/step - loss: 0.3706 - acc: 0.9817 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:34:03,044 [INFO] root: Training loop in progress
# Epoch 14/80
# 23/23 [==============================] - 5s 216ms/step - loss: 0.3496 - acc: 0.9896 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:34:08,635 [INFO] root: Training loop in progress
# Epoch 15/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3684 - acc: 0.9857 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:34:14,309 [INFO] root: Training loop in progress
# Epoch 16/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3620 - acc: 0.9857 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:34:19,954 [INFO] root: Training loop in progress
# Epoch 17/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3683 - acc: 0.9851 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:34:25,639 [INFO] root: Training loop in progress
# Epoch 18/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3770 - acc: 0.9878 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:34:31,266 [INFO] root: Training loop in progress
# Epoch 19/80
# 23/23 [==============================] - 5s 216ms/step - loss: 0.3717 - acc: 0.9801 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:34:36,855 [INFO] root: Training loop in progress
# Epoch 20/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3568 - acc: 0.9891 - val_loss: 0.2234 - val_acc: 1.0000
# 2022-08-09 04:34:42,451 [INFO] root: Training loop in progress
# Epoch 21/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3782 - acc: 0.9837 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:34:48,025 [INFO] root: Training loop in progress
# Epoch 22/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3572 - acc: 0.9904 - val_loss: 0.2234 - val_acc: 1.0000
# 2022-08-09 04:34:53,633 [INFO] root: Training loop in progress
# Epoch 23/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3685 - acc: 0.9878 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:34:59,226 [INFO] root: Training loop in progress
# Epoch 24/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3753 - acc: 0.9864 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:35:04,898 [INFO] root: Training loop in progress
# Epoch 25/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3588 - acc: 0.9810 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:35:10,554 [INFO] root: Training loop in progress
# Epoch 26/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3762 - acc: 0.9857 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:35:16,315 [INFO] root: Training loop in progress
# Epoch 27/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3636 - acc: 0.9830 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:35:21,927 [INFO] root: Training loop in progress
# Epoch 28/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3722 - acc: 0.9789 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:35:27,630 [INFO] root: Training loop in progress
# Epoch 29/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3652 - acc: 0.9891 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:35:33,267 [INFO] root: Training loop in progress
# Epoch 30/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3596 - acc: 0.9844 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:35:38,952 [INFO] root: Training loop in progress
# Epoch 31/80
# 23/23 [==============================] - 5s 223ms/step - loss: 0.3811 - acc: 0.9796 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:35:44,708 [INFO] root: Training loop in progress
# Epoch 32/80
# 23/23 [==============================] - 5s 223ms/step - loss: 0.3625 - acc: 0.9863 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:35:50,450 [INFO] root: Training loop in progress
# Epoch 33/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3573 - acc: 0.9823 - val_loss: 0.2234 - val_acc: 1.0000
# 2022-08-09 04:35:56,093 [INFO] root: Training loop in progress
# Epoch 34/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3747 - acc: 0.9816 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:36:01,692 [INFO] root: Training loop in progress
# Epoch 35/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3692 - acc: 0.9883 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:36:07,336 [INFO] root: Training loop in progress
# Epoch 36/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3566 - acc: 0.9869 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:36:12,981 [INFO] root: Training loop in progress
# Epoch 37/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3636 - acc: 0.9849 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:36:18,642 [INFO] root: Training loop in progress
# Epoch 38/80
# 23/23 [==============================] - 5s 216ms/step - loss: 0.3810 - acc: 0.9851 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:36:24,233 [INFO] root: Training loop in progress
# Epoch 39/80
# 23/23 [==============================] - 5s 221ms/step - loss: 0.3613 - acc: 0.9878 - val_loss: 0.2234 - val_acc: 1.0000
# 2022-08-09 04:36:29,950 [INFO] root: Training loop in progress
# Epoch 40/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3740 - acc: 0.9856 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:36:35,632 [INFO] root: Training loop in progress
# Epoch 41/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3643 - acc: 0.9850 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:36:41,261 [INFO] root: Training loop in progress
# Epoch 42/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3598 - acc: 0.9884 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:36:46,906 [INFO] root: Training loop in progress
# Epoch 43/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3830 - acc: 0.9776 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:36:52,566 [INFO] root: Training loop in progress
# Epoch 44/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3698 - acc: 0.9890 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:36:58,206 [INFO] root: Training loop in progress
# Epoch 45/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3773 - acc: 0.9815 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:37:03,886 [INFO] root: Training loop in progress
# Epoch 46/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3687 - acc: 0.9863 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:37:09,511 [INFO] root: Training loop in progress
# Epoch 47/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3758 - acc: 0.9857 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:37:15,214 [INFO] root: Training loop in progress
# Epoch 48/80
# 23/23 [==============================] - 5s 225ms/step - loss: 0.3705 - acc: 0.9878 - val_loss: 0.2234 - val_acc: 1.0000
# 2022-08-09 04:37:21,018 [INFO] root: Training loop in progress
# Epoch 49/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3787 - acc: 0.9848 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:37:26,621 [INFO] root: Training loop in progress
# Epoch 50/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3825 - acc: 0.9789 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:37:32,264 [INFO] root: Training loop in progress
# Epoch 51/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3743 - acc: 0.9835 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:37:37,893 [INFO] root: Training loop in progress
# Epoch 52/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3645 - acc: 0.9883 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:37:43,495 [INFO] root: Training loop in progress
# Epoch 53/80
# 23/23 [==============================] - 5s 221ms/step - loss: 0.3689 - acc: 0.9851 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:37:49,179 [INFO] root: Training loop in progress
# Epoch 54/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3670 - acc: 0.9863 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:37:54,796 [INFO] root: Training loop in progress
# Epoch 55/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3670 - acc: 0.9796 - val_loss: 0.2229 - val_acc: 1.0000
# 2022-08-09 04:38:00,429 [INFO] root: Training loop in progress
# Epoch 56/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3615 - acc: 0.9918 - val_loss: 0.2234 - val_acc: 1.0000
# 2022-08-09 04:38:06,115 [INFO] root: Training loop in progress
# Epoch 57/80
# 23/23 [==============================] - 5s 216ms/step - loss: 0.3682 - acc: 0.9883 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:38:11,667 [INFO] root: Training loop in progress
# Epoch 58/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3718 - acc: 0.9837 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:38:17,307 [INFO] root: Training loop in progress
# Epoch 59/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3714 - acc: 0.9836 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:38:22,903 [INFO] root: Training loop in progress
# Epoch 60/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3641 - acc: 0.9848 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:38:28,556 [INFO] root: Training loop in progress
# Epoch 61/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3572 - acc: 0.9829 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:38:34,195 [INFO] root: Training loop in progress
# Epoch 62/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3639 - acc: 0.9897 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:38:39,848 [INFO] root: Training loop in progress
# Epoch 63/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3711 - acc: 0.9905 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:38:45,474 [INFO] root: Training loop in progress
# Epoch 64/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3699 - acc: 0.9842 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:38:51,066 [INFO] root: Training loop in progress
# Epoch 65/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3693 - acc: 0.9836 - val_loss: 0.2229 - val_acc: 1.0000
# 2022-08-09 04:38:56,788 [INFO] root: Training loop in progress
# Epoch 66/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3592 - acc: 0.9871 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:39:02,451 [INFO] root: Training loop in progress
# Epoch 67/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3664 - acc: 0.9829 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:39:08,089 [INFO] root: Training loop in progress
# Epoch 68/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3732 - acc: 0.9836 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:39:13,742 [INFO] root: Training loop in progress
# Epoch 69/80
# 23/23 [==============================] - 5s 223ms/step - loss: 0.3637 - acc: 0.9884 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:39:19,466 [INFO] root: Training loop in progress
# Epoch 70/80
# 23/23 [==============================] - 5s 217ms/step - loss: 0.3608 - acc: 0.9878 - val_loss: 0.2233 - val_acc: 1.0000
# 2022-08-09 04:39:25,093 [INFO] root: Training loop in progress
# Epoch 71/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3802 - acc: 0.9850 - val_loss: 0.2230 - val_acc: 1.0000
# 2022-08-09 04:39:30,762 [INFO] root: Training loop in progress
# Epoch 72/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3582 - acc: 0.9863 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:39:36,463 [INFO] root: Training loop in progress
# Epoch 73/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3612 - acc: 0.9912 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:39:42,094 [INFO] root: Training loop in progress
# Epoch 74/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3738 - acc: 0.9809 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:39:47,746 [INFO] root: Training loop in progress
# Epoch 75/80
# 23/23 [==============================] - 5s 218ms/step - loss: 0.3701 - acc: 0.9884 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:39:53,325 [INFO] root: Training loop in progress
# Epoch 76/80
# 23/23 [==============================] - 5s 221ms/step - loss: 0.3657 - acc: 0.9863 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:39:59,024 [INFO] root: Training loop in progress
# Epoch 77/80
# 23/23 [==============================] - 5s 215ms/step - loss: 0.3732 - acc: 0.9850 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:40:04,560 [INFO] root: Training loop in progress
# Epoch 78/80
# 23/23 [==============================] - 5s 219ms/step - loss: 0.3690 - acc: 0.9884 - val_loss: 0.2231 - val_acc: 1.0000
# 2022-08-09 04:40:10,275 [INFO] root: Training loop in progress
# Epoch 79/80
# 23/23 [==============================] - 5s 220ms/step - loss: 0.3664 - acc: 0.9871 - val_loss: 0.2232 - val_acc: 1.0000
# 2022-08-09 04:40:16,005 [INFO] root: Training loop in progress
# Epoch 80/80
# 23/23 [==============================] - 5s 221ms/step - loss: 0.3699 - acc: 0.9841 - val_loss: 0.2236 - val_acc: 1.0000
# 2022-08-09 04:40:21,707 [INFO] root: Training loop in progress
# 2022-08-09 04:40:21,733 [INFO] root: Training loop complete.
# 2022-08-09 04:40:21,736 [INFO] root: Final model evaluation in progress.
# 2022-08-09 04:40:23,552 [INFO] root: Model evaluation in complete.
# 2022-08-09 04:40:23,552 [INFO] __main__: Total Val Loss: 0.22361133992671967
# 2022-08-09 04:40:23,552 [INFO] __main__: Total Val accuracy: 1.0
# 2022-08-09 04:40:23,552 [INFO] root: Training finished successfully.
# 2022-08-09 04:40:23,552 [INFO] __main__: Training finished successfully.
# 2022-08-09 04:40:25,881 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao classification evaluate -e $SPECS_DIR/classification_googlenet.cfg -k $KEY
# Out:
# 2022-08-09 05:01:53,360 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 05:01:53,523 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:32: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:32: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# INFO: Loading experiment spec at /workspace/faceclassification/specs/classification_googlenet.cfg.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING: From /opt/nvidia/third_party/keras/tensorflow_backend.py:183: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 224, 224)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 112, 112) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 112, 112) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 112, 112) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 64, 56, 56)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2_reduce (Conv2D)           (None, 64, 56, 56)   4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn_conv2_reduce (BatchNormaliza (None, 64, 56, 56)   256         conv2_reduce[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 56, 56)   0           bn_conv2_reduce[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 192, 56, 56)  110592      activation_2[0][0]
# __________________________________________________________________________________________________
# bn_conv2 (BatchNormalization)   (None, 192, 56, 56)  768         conv2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 192, 56, 56)  0           bn_conv2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 192, 28, 28)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce (Conv2D (None, 96, 28, 28)   18432       pool2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_reduce (Conv2D (None, 16, 28, 28)   3072        pool2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_reduce_bn (Bat (None, 96, 28, 28)   384         inception_3a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_reduce_bn (Bat (None, 16, 28, 28)   64          inception_3a_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 96, 28, 28)   0           inception_3a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 28, 28)   0           inception_3a_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool (MaxPooling2D (None, 192, 28, 28)  0           pool2[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1 (Conv2D)       (None, 64, 28, 28)   12288       pool2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3 (Conv2D)       (None, 128, 28, 28)  110592      activation_5[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5 (Conv2D)       (None, 32, 28, 28)   12800       activation_7[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj (Conv2D) (None, 32, 28, 28)   6144        inception_3a_pool[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 64, 28, 28)   256         inception_3a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn (BatchNorma (None, 128, 28, 28)  512         inception_3a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn (BatchNorma (None, 32, 28, 28)   128         inception_3a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_proj_bn (Batc (None, 32, 28, 28)   128         inception_3a_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 28, 28)   0           inception_3a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 28, 28)  0           inception_3a_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 28, 28)   0           inception_3a_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 28, 28)   0           inception_3a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_output (Concatenat (None, 256, 28, 28)  0           activation_4[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce (Conv2D (None, 128, 28, 28)  32768       inception_3a_output[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_reduce (Conv2D (None, 32, 28, 28)   8192        inception_3a_output[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_reduce_bn (Bat (None, 128, 28, 28)  512         inception_3b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_reduce_bn (Bat (None, 32, 28, 28)   128         inception_3b_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 28, 28)  0           inception_3b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 28, 28)   0           inception_3b_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool (MaxPooling2D (None, 256, 28, 28)  0           inception_3a_output[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1 (Conv2D)       (None, 128, 28, 28)  32768       inception_3a_output[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3 (Conv2D)       (None, 192, 28, 28)  221184      activation_11[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5 (Conv2D)       (None, 96, 28, 28)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj (Conv2D) (None, 64, 28, 28)   16384       inception_3b_pool[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 128, 28, 28)  512         inception_3b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn (BatchNorma (None, 192, 28, 28)  768         inception_3b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn (BatchNorma (None, 96, 28, 28)   384         inception_3b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_proj_bn (Batc (None, 64, 28, 28)   256         inception_3b_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 28, 28)  0           inception_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 192, 28, 28)  0           inception_3b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 96, 28, 28)   0           inception_3b_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 28, 28)   0           inception_3b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_output (Concatenat (None, 480, 28, 28)  0           activation_10[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 480, 14, 14)  0           inception_3b_output[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce (Conv2D (None, 96, 14, 14)   46080       pool3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_reduce (Conv2D (None, 16, 14, 14)   7680        pool3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_reduce_bn (Bat (None, 96, 14, 14)   384         inception_4a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_reduce_bn (Bat (None, 16, 14, 14)   64          inception_4a_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 96, 14, 14)   0           inception_4a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 14, 14)   0           inception_4a_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool (MaxPooling2D (None, 480, 14, 14)  0           pool3[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1 (Conv2D)       (None, 192, 14, 14)  92160       pool3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3 (Conv2D)       (None, 208, 14, 14)  179712      activation_17[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5 (Conv2D)       (None, 48, 14, 14)   19200       activation_19[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj (Conv2D) (None, 64, 14, 14)   30720       inception_4a_pool[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 192, 14, 14)  768         inception_4a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn (BatchNorma (None, 208, 14, 14)  832         inception_4a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn (BatchNorma (None, 48, 14, 14)   192         inception_4a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_proj_bn (Batc (None, 64, 14, 14)   256         inception_4a_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 192, 14, 14)  0           inception_4a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 208, 14, 14)  0           inception_4a_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 48, 14, 14)   0           inception_4a_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 14, 14)   0           inception_4a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_output (Concatenat (None, 512, 14, 14)  0           activation_16[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce (Conv2D (None, 112, 14, 14)  57344       inception_4a_output[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_reduce (Conv2D (None, 24, 14, 14)   12288       inception_4a_output[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_reduce_bn (Bat (None, 112, 14, 14)  448         inception_4b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_reduce_bn (Bat (None, 24, 14, 14)   96          inception_4b_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 112, 14, 14)  0           inception_4b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 24, 14, 14)   0           inception_4b_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool (MaxPooling2D (None, 512, 14, 14)  0           inception_4a_output[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1 (Conv2D)       (None, 160, 14, 14)  81920       inception_4a_output[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3 (Conv2D)       (None, 224, 14, 14)  225792      activation_23[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5 (Conv2D)       (None, 64, 14, 14)   38400       activation_25[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj (Conv2D) (None, 64, 14, 14)   32768       inception_4b_pool[0][0]
# __________________________________________________________________________________________________
# inception_4b_1x1_bn (BatchNorma (None, 160, 14, 14)  640         inception_4b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4b_3x3_bn (BatchNorma (None, 224, 14, 14)  896         inception_4b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4b_5x5_bn (BatchNorma (None, 64, 14, 14)   256         inception_4b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4b_pool_proj_bn (Batc (None, 64, 14, 14)   256         inception_4b_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 160, 14, 14)  0           inception_4b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 224, 14, 14)  0           inception_4b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 14, 14)   0           inception_4b_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 14, 14)   0           inception_4b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4b_output (Concatenat (None, 512, 14, 14)  0           activation_22[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce (Conv2D (None, 128, 14, 14)  65536       inception_4b_output[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_reduce (Conv2D (None, 24, 14, 14)   12288       inception_4b_output[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_reduce_bn (Bat (None, 128, 14, 14)  512         inception_4c_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_reduce_bn (Bat (None, 24, 14, 14)   96          inception_4c_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 128, 14, 14)  0           inception_4c_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 24, 14, 14)   0           inception_4c_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool (MaxPooling2D (None, 512, 14, 14)  0           inception_4b_output[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1 (Conv2D)       (None, 128, 14, 14)  65536       inception_4b_output[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3 (Conv2D)       (None, 256, 14, 14)  294912      activation_29[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5 (Conv2D)       (None, 64, 14, 14)   38400       activation_31[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj (Conv2D) (None, 64, 14, 14)   32768       inception_4c_pool[0][0]
# __________________________________________________________________________________________________
# inception_4c_1x1_bn (BatchNorma (None, 128, 14, 14)  512         inception_4c_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4c_3x3_bn (BatchNorma (None, 256, 14, 14)  1024        inception_4c_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4c_5x5_bn (BatchNorma (None, 64, 14, 14)   256         inception_4c_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4c_pool_proj_bn (Batc (None, 64, 14, 14)   256         inception_4c_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 14, 14)  0           inception_4c_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 256, 14, 14)  0           inception_4c_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 14, 14)   0           inception_4c_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 14, 14)   0           inception_4c_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4c_output (Concatenat (None, 512, 14, 14)  0           activation_28[0][0]
#                                                                  activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce (Conv2D (None, 144, 14, 14)  73728       inception_4c_output[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_reduce (Conv2D (None, 32, 14, 14)   16384       inception_4c_output[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_reduce_bn (Bat (None, 144, 14, 14)  576         inception_4d_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_reduce_bn (Bat (None, 32, 14, 14)   128         inception_4d_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 144, 14, 14)  0           inception_4d_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 14, 14)   0           inception_4d_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool (MaxPooling2D (None, 512, 14, 14)  0           inception_4c_output[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1 (Conv2D)       (None, 112, 14, 14)  57344       inception_4c_output[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3 (Conv2D)       (None, 288, 14, 14)  373248      activation_35[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5 (Conv2D)       (None, 64, 14, 14)   51200       activation_37[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj (Conv2D) (None, 64, 14, 14)   32768       inception_4d_pool[0][0]
# __________________________________________________________________________________________________
# inception_4d_1x1_bn (BatchNorma (None, 112, 14, 14)  448         inception_4d_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4d_3x3_bn (BatchNorma (None, 288, 14, 14)  1152        inception_4d_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4d_5x5_bn (BatchNorma (None, 64, 14, 14)   256         inception_4d_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4d_pool_proj_bn (Batc (None, 64, 14, 14)   256         inception_4d_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 112, 14, 14)  0           inception_4d_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 288, 14, 14)  0           inception_4d_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 14, 14)   0           inception_4d_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 14, 14)   0           inception_4d_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4d_output (Concatenat (None, 528, 14, 14)  0           activation_34[0][0]
#                                                                  activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce (Conv2D (None, 160, 14, 14)  84480       inception_4d_output[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_reduce (Conv2D (None, 32, 14, 14)   16896       inception_4d_output[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_reduce_bn (Bat (None, 160, 14, 14)  640         inception_4e_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_reduce_bn (Bat (None, 32, 14, 14)   128         inception_4e_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 160, 14, 14)  0           inception_4e_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 14, 14)   0           inception_4e_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool (MaxPooling2D (None, 528, 14, 14)  0           inception_4d_output[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1 (Conv2D)       (None, 256, 14, 14)  135168      inception_4d_output[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3 (Conv2D)       (None, 320, 14, 14)  460800      activation_41[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5 (Conv2D)       (None, 128, 14, 14)  102400      activation_43[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj (Conv2D) (None, 128, 14, 14)  67584       inception_4e_pool[0][0]
# __________________________________________________________________________________________________
# inception_4e_1x1_bn (BatchNorma (None, 256, 14, 14)  1024        inception_4e_1x1[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn (BatchNorma (None, 320, 14, 14)  1280        inception_4e_3x3[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn (BatchNorma (None, 128, 14, 14)  512         inception_4e_5x5[0][0]
# __________________________________________________________________________________________________
# inception_4e_pool_proj_bn (Batc (None, 128, 14, 14)  512         inception_4e_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 256, 14, 14)  0           inception_4e_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 320, 14, 14)  0           inception_4e_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 128, 14, 14)  0           inception_4e_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 128, 14, 14)  0           inception_4e_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_4e_output (Concatenat (None, 832, 14, 14)  0           activation_40[0][0]
#                                                                  activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 832, 7, 7)    0           inception_4e_output[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce (Conv2D (None, 160, 7, 7)    133120      pool4[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_reduce (Conv2D (None, 32, 7, 7)     26624       pool4[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_reduce_bn (Bat (None, 160, 7, 7)    640         inception_5a_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_reduce_bn (Bat (None, 32, 7, 7)     128         inception_5a_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 160, 7, 7)    0           inception_5a_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7)     0           inception_5a_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool (MaxPooling2D (None, 832, 7, 7)    0           pool4[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1 (Conv2D)       (None, 256, 7, 7)    212992      pool4[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3 (Conv2D)       (None, 320, 7, 7)    460800      activation_47[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5 (Conv2D)       (None, 128, 7, 7)    102400      activation_49[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj (Conv2D) (None, 128, 7, 7)    106496      inception_5a_pool[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 256, 7, 7)    1024        inception_5a_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn (BatchNorma (None, 320, 7, 7)    1280        inception_5a_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5a_5x5_bn (BatchNorma (None, 128, 7, 7)    512         inception_5a_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_proj_bn (Batc (None, 128, 7, 7)    512         inception_5a_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 256, 7, 7)    0           inception_5a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 320, 7, 7)    0           inception_5a_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 7, 7)    0           inception_5a_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 128, 7, 7)    0           inception_5a_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_output (Concatenat (None, 832, 7, 7)    0           activation_46[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce (Conv2D (None, 192, 7, 7)    159744      inception_5a_output[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_reduce (Conv2D (None, 48, 7, 7)     39936       inception_5a_output[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_reduce_bn (Bat (None, 192, 7, 7)    768         inception_5b_3x3_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_reduce_bn (Bat (None, 48, 7, 7)     192         inception_5b_5x5_reduce[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 192, 7, 7)    0           inception_5b_3x3_reduce_bn[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 48, 7, 7)     0           inception_5b_5x5_reduce_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool (MaxPooling2D (None, 832, 7, 7)    0           inception_5a_output[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1 (Conv2D)       (None, 384, 7, 7)    319488      inception_5a_output[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3 (Conv2D)       (None, 384, 7, 7)    663552      activation_53[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5 (Conv2D)       (None, 128, 7, 7)    153600      activation_55[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj (Conv2D) (None, 128, 7, 7)    106496      inception_5b_pool[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 384, 7, 7)    1536        inception_5b_1x1[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn (BatchNorma (None, 384, 7, 7)    1536        inception_5b_3x3[0][0]
# __________________________________________________________________________________________________
# inception_5b_5x5_bn (BatchNorma (None, 128, 7, 7)    512         inception_5b_5x5[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_proj_bn (Batc (None, 128, 7, 7)    512         inception_5b_pool_proj[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 384, 7, 7)    0           inception_5b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 384, 7, 7)    0           inception_5b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 128, 7, 7)    0           inception_5b_5x5_bn[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 128, 7, 7)    0           inception_5b_pool_proj_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_output (Concatenat (None, 1024, 7, 7)   0           activation_52[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1024, 7, 7)   0           inception_5b_output[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 50176)        0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50176)        0           flatten[0][0]
# __________________________________________________________________________________________________
# output_fc (Dense)               (None, 3)            150531      dropout_1[0][0]
# ==================================================================================================
# Total params: 6,145,923
# Trainable params: 5,843,939
# Non-trainable params: 301,984
# __________________________________________________________________________________________________
# Found 39 images belonging to 3 classes.
# INFO: Processing dataset (evaluation): /workspace/data/test
# Evaluation Loss: 0.7278963923454285
# Evaluation Top K accuracy: 1.0
# Found 39 images belonging to 3 classes.
# INFO: Calculating per-class P/R and confusion matrix. It may take a while...
# Confusion Matrix
# [[ 9  1  0]
#  [ 0 13  1]
#  [ 0  0 15]]
# Classification Report
#               precision    recall  f1-score   support
#
#        agung       1.00      0.90      0.95        10
#       raisul       0.93      0.93      0.93        14
#        yatna       0.94      1.00      0.97        15
#
#     accuracy                           0.95        39
#    macro avg       0.96      0.94      0.95        39
# weighted avg       0.95      0.95      0.95        39
#
# 2022-08-09 05:02:32,755 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao classification evaluate -e $SPECS_DIR/classification_mobilenet.cfg -k $KEY
# Out:
# 2022-08-09 04:50:54,454 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 04:50:54,620 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:32: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:32: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# INFO: Loading experiment spec at /workspace/faceclassification/specs/classification_mobilenet.cfg.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 224, 224)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 3, 226, 226)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 112, 112)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 112, 112)      128
# _________________________________________________________________
# conv_block_relu (ReLU)       (None, 32, 112, 112)      0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, 32, 114, 114)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 112, 112)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 112, 112)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 112, 112)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 64, 112, 112)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 64, 112, 112)      256
# _________________________________________________________________
# conv_pw_relu_1 (ReLU)        (None, 64, 112, 112)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 64, 114, 114)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 64, 56, 56)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 64, 56, 56)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 64, 56, 56)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 128, 56, 56)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 128, 56, 56)       512
# _________________________________________________________________
# conv_pw_relu_2 (ReLU)        (None, 128, 56, 56)       0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, 128, 58, 58)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 128, 56, 56)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 128, 56, 56)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 128, 56, 56)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 128, 56, 56)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 128, 56, 56)       512
# _________________________________________________________________
# conv_pw_relu_3 (ReLU)        (None, 128, 56, 56)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 128, 58, 58)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 128, 28, 28)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 128, 28, 28)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 128, 28, 28)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 256, 28, 28)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 256, 28, 28)       1024
# _________________________________________________________________
# conv_pw_relu_4 (ReLU)        (None, 256, 28, 28)       0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, 256, 30, 30)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 256, 28, 28)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 256, 28, 28)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 256, 28, 28)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 256, 28, 28)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 256, 28, 28)       1024
# _________________________________________________________________
# conv_pw_relu_5 (ReLU)        (None, 256, 28, 28)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 256, 30, 30)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 256, 14, 14)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 256, 14, 14)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 256, 14, 14)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 512, 14, 14)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_6 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_7 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_8 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_9 (ReLU)        (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_10 (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 512, 14, 14)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 512, 14, 14)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 512, 14, 14)       2048
# _________________________________________________________________
# conv_pw_relu_11 (ReLU)       (None, 512, 14, 14)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 512, 16, 16)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 512, 7, 7)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 512, 7, 7)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 512, 7, 7)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 1024, 7, 7)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_pw_relu_12 (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, 1024, 9, 9)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 1024, 7, 7)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 1024, 7, 7)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_pw_relu_13 (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1024, 1, 1)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# predictions (Dense)          (None, 3)                 3075
# =================================================================
# Total params: 3,231,939
# Trainable params: 3,206,851
# Non-trainable params: 25,088
# _________________________________________________________________
# Found 39 images belonging to 3 classes.
# INFO: Processing dataset (evaluation): /workspace/data/test
# Evaluation Loss: 0.2817843556404114
# Evaluation Top K accuracy: 1.0
# Found 39 images belonging to 3 classes.
# INFO: Calculating per-class P/R and confusion matrix. It may take a while...
# Confusion Matrix
# [[ 9  1  0]
#  [ 0 14  0]
#  [ 0  1 14]]
# Classification Report
#               precision    recall  f1-score   support
#
#        agung       1.00      0.90      0.95        10
#       raisul       0.88      1.00      0.93        14
#        yatna       1.00      0.93      0.97        15
#
#     accuracy                           0.95        39
#    macro avg       0.96      0.94      0.95        39
# weighted avg       0.96      0.95      0.95        39
#
# 2022-08-09 04:51:19,607 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %% [markdown]
# #### 2.3 Pruning the model

# %%
# Defining the checkpoint epoch number of the model to be used for the pruning.
# This should be lesser than the number of epochs training has been run for, incase training was interrupted earlier.
# By default, the default final model is at epoch 080.
# %env EPOCH=080
# !mkdir -p $LOCAL_EXPERIMENT_DIR/output/mobilenetv1_pruned
# !tao classification prune -m $USER_EXPERIMENT_DIR/output/weights/mobilenet_v1_$EPOCH.tlt \
           -o $USER_EXPERIMENT_DIR/output/mobilenetv1_pruned/mobilenet_v1_nopool_bn_pruned.tlt \
           -eq union \
           -pth 0.6 \
           -k $KEY \
           --results_dir $USER_EXPERIMENT_DIR/logs
# Out:
# env: EPOCH=080
# 2022-08-09 05:07:32,657 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 05:07:32,820 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2022-08-09 05:07:41,314 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/logs/status.json
# 2022-08-09 05:07:44,671 [INFO] modulus.pruning.pruning: Exploring graph for retainable indices
# 2022-08-09 05:07:45,582 [INFO] modulus.pruning.pruning: Pruning model and appending pruned nodes to new graph
# 2022-08-09 05:08:13,560 [INFO] iva.common.magnet_prune: Pruning ratio (pruned model / original model): 0.5404517226346166
# 2022-08-09 05:08:13,824 [INFO] root: Pruning ratio (pruned model / original model): 0.5404517226346166
# 2022-08-09 05:08:15,430 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao classification train -e $SPECS_DIR/classification_retrain_mobilenet.cfg \
                      -r $USER_EXPERIMENT_DIR/output_retrain \
                      -k $KEY
# Out:
# 2022-08-09 05:49:59,480 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 05:49:59,622 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2022-08-09 05:50:08,762 [INFO] __main__: Loading experiment spec at /workspace/faceclassification/specs/classification_retrain_mobilenet.cfg.
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:384: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-08-09 05:50:08,772 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:384: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:393: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-08-09 05:50:08,773 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:393: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-08-09 05:50:09,451 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/output_retrain/status.json
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2022-08-09 05:50:09,451 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-08-09 05:50:09,451 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/train.py:417: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-08-09 05:50:09,451 [INFO] __main__: Default image mean [103.939, 116.779, 123.68] will be used.
# Found 1465 images belonging to 3 classes.
# 2022-08-09 05:50:09,563 [INFO] __main__: Processing dataset (train): /workspace/data/train
# Found 203 images belonging to 3 classes.
# 2022-08-09 05:50:09,669 [INFO] __main__: Processing dataset (validation): /workspace/data/val
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2022-08-09 05:50:09,670 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2022-08-09 05:50:09,671 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2022-08-09 05:50:09,682 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2022-08-09 05:50:09,700 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2022-08-09 05:50:09,707 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2022-08-09 05:50:10,660 [WARNING] tensorflow: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2022-08-09 05:50:11,565 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2022-08-09 05:50:11,565 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2022-08-09 05:50:11,566 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2022-08-09 05:50:12,157 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 224, 224)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 3, 226, 226)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 16, 112, 112)      432
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 16, 112, 112)      64
# _________________________________________________________________
# conv_block_relu (ReLU)       (None, 16, 112, 112)      0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, 16, 114, 114)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 16, 112, 112)      144
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 16, 112, 112)      64
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 16, 112, 112)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 56, 112, 112)      896
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 56, 112, 112)      224
# _________________________________________________________________
# conv_pw_relu_1 (ReLU)        (None, 56, 112, 112)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 56, 114, 114)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 56)        504
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 56)        224
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 56)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 56)        3136
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 56)        224
# _________________________________________________________________
# conv_pw_relu_2 (ReLU)        (None, 56, 56, 56)        0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, 56, 58, 58)        0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 56)        504
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 56)        224
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 56)        0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 120, 56, 56)       6720
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 120, 56, 56)       480
# _________________________________________________________________
# conv_pw_relu_3 (ReLU)        (None, 120, 56, 56)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 120, 58, 58)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 120, 28, 28)       1080
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 120, 28, 28)       480
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 120, 28, 28)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 152, 28, 28)       18240
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 152, 28, 28)       608
# _________________________________________________________________
# conv_pw_relu_4 (ReLU)        (None, 152, 28, 28)       0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, 152, 30, 30)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 152, 28, 28)       1368
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 152, 28, 28)       608
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 152, 28, 28)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 184, 28, 28)       27968
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 184, 28, 28)       736
# _________________________________________________________________
# conv_pw_relu_5 (ReLU)        (None, 184, 28, 28)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 184, 30, 30)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 184, 14, 14)       1656
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 184, 14, 14)       736
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 184, 14, 14)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 232, 14, 14)       42688
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 232, 14, 14)       928
# _________________________________________________________________
# conv_pw_relu_6 (ReLU)        (None, 232, 14, 14)       0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, 232, 16, 16)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 232, 14, 14)       2088
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 232, 14, 14)       928
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 232, 14, 14)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 288, 14, 14)       66816
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 288, 14, 14)       1152
# _________________________________________________________________
# conv_pw_relu_7 (ReLU)        (None, 288, 14, 14)       0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, 288, 16, 16)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 288, 14, 14)       2592
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 288, 14, 14)       1152
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 288, 14, 14)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 360, 14, 14)       103680
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 360, 14, 14)       1440
# _________________________________________________________________
# conv_pw_relu_8 (ReLU)        (None, 360, 14, 14)       0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, 360, 16, 16)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 360, 14, 14)       3240
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 360, 14, 14)       1440
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 360, 14, 14)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 384, 14, 14)       138240
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 384, 14, 14)       1536
# _________________________________________________________________
# conv_pw_relu_9 (ReLU)        (None, 384, 14, 14)       0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, 384, 16, 16)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 384, 14, 14)       3456
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 384, 14, 14)       1536
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 384, 14, 14)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 488, 14, 14)       187392
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 488, 14, 14)       1952
# _________________________________________________________________
# conv_pw_relu_10 (ReLU)       (None, 488, 14, 14)       0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, 488, 16, 16)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 488, 14, 14)       4392
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 488, 14, 14)       1952
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 488, 14, 14)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 392, 14, 14)       191296
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 392, 14, 14)       1568
# _________________________________________________________________
# conv_pw_relu_11 (ReLU)       (None, 392, 14, 14)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 392, 16, 16)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 392, 7, 7)         3528
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 392, 7, 7)         1568
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 392, 7, 7)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 632, 7, 7)         247744
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 632, 7, 7)         2528
# _________________________________________________________________
# conv_pw_relu_12 (ReLU)       (None, 632, 7, 7)         0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, 632, 9, 9)         0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 632, 7, 7)         5688
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 632, 7, 7)         2528
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 632, 7, 7)         0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 1024, 7, 7)        647168
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_pw_relu_13 (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1024, 1, 1)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# predictions (Dense)          (None, 3)                 3075
# =================================================================
# Total params: 1,746,707
# Trainable params: 1,729,747
# Non-trainable params: 16,960
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 2022-08-09 05:50:43,699 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# 2022-08-09 05:50:43,712 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1123: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-08-09 05:50:43,728 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1123: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-08-09 05:50:43,728 [INFO] iva.common.logging.logging: Log file already exists at /workspace/faceclassification/output_retrain/status.json
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# 2022-08-09 05:50:45,496 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2022-08-09 05:50:45,677 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 2022-08-09 05:50:47,285 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:1171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# 2022-08-09 05:50:48,475 [INFO] root: Starting Training Loop.
# Epoch 1/80
#  1/23 [>.............................] - ETA: 4:20 - loss: 0.6146 - acc: 0.8906WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:186: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# 2022-08-09 05:51:03,278 [WARNING] tensorflow: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/utils.py:186: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
#  2/23 [=>............................] - ETA: 2:40 - loss: 0.6206 - acc: 0.8672/usr/local/lib/python3.6/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.615818). Check your callbacks.
#   % delta_t_median)
# 23/23 [==============================] - 24s 1s/step - loss: 0.4154 - acc: 0.9461 - val_loss: 0.1655 - val_acc: 1.0000
# e635b53343a6:76:107 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.4<0>
# e635b53343a6:76:107 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# e635b53343a6:76:107 [0] NCCL INFO P2P plugin IBext
# e635b53343a6:76:107 [0] NCCL INFO NET/IB : No device found.
# e635b53343a6:76:107 [0] NCCL INFO NET/IB : No device found.
# e635b53343a6:76:107 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.4<0>
# e635b53343a6:76:107 [0] NCCL INFO Using network Socket
# NCCL version 2.11.4+cuda11.6
# e635b53343a6:76:107 [0] NCCL INFO Channel 00/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 01/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 02/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 03/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 04/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 05/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 06/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 07/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 08/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 09/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 10/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 11/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 12/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 13/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 14/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 15/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 16/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 17/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 18/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 19/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 20/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 21/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 22/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 23/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 24/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 25/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 26/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 27/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 28/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 29/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 30/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Channel 31/32 :    0
# e635b53343a6:76:107 [0] NCCL INFO Trees [0] -1/-1/-1->0->-1 [1] -1/-1/-1->0->-1 [2] -1/-1/-1->0->-1 [3] -1/-1/-1->0->-1 [4] -1/-1/-1->0->-1 [5] -1/-1/-1->0->-1 [6] -1/-1/-1->0->-1 [7] -1/-1/-1->0->-1 [8] -1/-1/-1->0->-1 [9] -1/-1/-1->0->-1 [10] -1/-1/-1->0->-1 [11] -1/-1/-1->0->-1 [12] -1/-1/-1->0->-1 [13] -1/-1/-1->0->-1 [14] -1/-1/-1->0->-1 [15] -1/-1/-1->0->-1 [16] -1/-1/-1->0->-1 [17] -1/-1/-1->0->-1 [18] -1/-1/-1->0->-1 [19] -1/-1/-1->0->-1 [20] -1/-1/-1->0->-1 [21] -1/-1/-1->0->-1 [22] -1/-1/-1->0->-1 [23] -1/-1/-1->0->-1 [24] -1/-1/-1->0->-1 [25] -1/-1/-1->0->-1 [26] -1/-1/-1->0->-1 [27] -1/-1/-1->0->-1 [28] -1/-1/-1->0->-1 [29] -1/-1/-1->0->-1 [30] -1/-1/-1->0->-1 [31] -1/-1/-1->0->-1
# e635b53343a6:76:107 [0] NCCL INFO Connected all rings
# e635b53343a6:76:107 [0] NCCL INFO Connected all trees
# e635b53343a6:76:107 [0] NCCL INFO 32 coll channels, 32 p2p channels, 32 p2p channels per peer
# e635b53343a6:76:107 [0] NCCL INFO comm 0x7f6420354a00 rank 0 nranks 1 cudaDev 0 busId 3000 - Init COMPLETE
# 2022-08-09 05:51:22,976 [INFO] root: Training loop in progress
# Epoch 2/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.3151 - acc: 0.9789 - val_loss: 0.1438 - val_acc: 1.0000
# 2022-08-09 05:51:32,222 [INFO] root: Training loop in progress
# Epoch 3/80
# 23/23 [==============================] - 4s 174ms/step - loss: 0.2862 - acc: 0.9823 - val_loss: 0.1448 - val_acc: 1.0000
# 2022-08-09 05:51:37,357 [INFO] root: Training loop in progress
# Epoch 4/80
# 23/23 [==============================] - 4s 174ms/step - loss: 0.2992 - acc: 0.9884 - val_loss: 0.1469 - val_acc: 1.0000
# 2022-08-09 05:51:41,870 [INFO] root: Training loop in progress
# Epoch 5/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2922 - acc: 0.9864 - val_loss: 0.1480 - val_acc: 1.0000
# 2022-08-09 05:51:46,504 [INFO] root: Training loop in progress
# Epoch 6/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.3012 - acc: 0.9844 - val_loss: 0.1476 - val_acc: 1.0000
# 2022-08-09 05:51:51,123 [INFO] root: Training loop in progress
# Epoch 7/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2868 - acc: 0.9925 - val_loss: 0.1489 - val_acc: 1.0000
# 2022-08-09 05:51:55,716 [INFO] root: Training loop in progress
# Epoch 8/80
# 23/23 [==============================] - 4s 183ms/step - loss: 0.2996 - acc: 0.9796 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:52:00,493 [INFO] root: Training loop in progress
# Epoch 9/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2897 - acc: 0.9851 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:52:05,139 [INFO] root: Training loop in progress
# Epoch 10/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2932 - acc: 0.9877 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:52:09,732 [INFO] root: Training loop in progress
# Epoch 11/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2902 - acc: 0.9829 - val_loss: 0.1494 - val_acc: 1.0000
# 2022-08-09 05:52:14,320 [INFO] root: Training loop in progress
# Epoch 12/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2801 - acc: 0.9809 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:52:18,981 [INFO] root: Training loop in progress
# Epoch 13/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2961 - acc: 0.9829 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:52:23,571 [INFO] root: Training loop in progress
# Epoch 14/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2857 - acc: 0.9836 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:52:28,201 [INFO] root: Training loop in progress
# Epoch 15/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2794 - acc: 0.9884 - val_loss: 0.1479 - val_acc: 1.0000
# 2022-08-09 05:52:32,772 [INFO] root: Training loop in progress
# Epoch 16/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2896 - acc: 0.9871 - val_loss: 0.1485 - val_acc: 1.0000
# 2022-08-09 05:52:37,454 [INFO] root: Training loop in progress
# Epoch 17/80
# 23/23 [==============================] - 4s 174ms/step - loss: 0.2845 - acc: 0.9842 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:52:42,015 [INFO] root: Training loop in progress
# Epoch 18/80
# 23/23 [==============================] - 4s 180ms/step - loss: 0.3092 - acc: 0.9843 - val_loss: 0.1480 - val_acc: 1.0000
# 2022-08-09 05:52:46,814 [INFO] root: Training loop in progress
# Epoch 19/80
# 23/23 [==============================] - 4s 181ms/step - loss: 0.2866 - acc: 0.9857 - val_loss: 0.1489 - val_acc: 1.0000
# 2022-08-09 05:52:51,563 [INFO] root: Training loop in progress
# Epoch 20/80
# 23/23 [==============================] - 4s 174ms/step - loss: 0.2765 - acc: 0.9904 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:52:56,123 [INFO] root: Training loop in progress
# Epoch 21/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2740 - acc: 0.9829 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:53:00,746 [INFO] root: Training loop in progress
# Epoch 22/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2739 - acc: 0.9864 - val_loss: 0.1489 - val_acc: 1.0000
# 2022-08-09 05:53:05,310 [INFO] root: Training loop in progress
# Epoch 23/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2982 - acc: 0.9823 - val_loss: 0.1492 - val_acc: 1.0000
# 2022-08-09 05:53:09,986 [INFO] root: Training loop in progress
# Epoch 24/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2895 - acc: 0.9851 - val_loss: 0.1481 - val_acc: 1.0000
# 2022-08-09 05:53:14,617 [INFO] root: Training loop in progress
# Epoch 25/80
# 23/23 [==============================] - 4s 180ms/step - loss: 0.3073 - acc: 0.9781 - val_loss: 0.1485 - val_acc: 1.0000
# 2022-08-09 05:53:19,301 [INFO] root: Training loop in progress
# Epoch 26/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2833 - acc: 0.9891 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:53:23,836 [INFO] root: Training loop in progress
# Epoch 27/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2943 - acc: 0.9864 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:53:28,502 [INFO] root: Training loop in progress
# Epoch 28/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.2816 - acc: 0.9878 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:53:33,152 [INFO] root: Training loop in progress
# Epoch 29/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2810 - acc: 0.9890 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:53:37,725 [INFO] root: Training loop in progress
# Epoch 30/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2953 - acc: 0.9823 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:53:42,306 [INFO] root: Training loop in progress
# Epoch 31/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2972 - acc: 0.9843 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:53:46,958 [INFO] root: Training loop in progress
# Epoch 32/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2974 - acc: 0.9837 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:53:51,624 [INFO] root: Training loop in progress
# Epoch 33/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2814 - acc: 0.9890 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:53:56,207 [INFO] root: Training loop in progress
# Epoch 34/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2847 - acc: 0.9837 - val_loss: 0.1485 - val_acc: 1.0000
# 2022-08-09 05:54:00,879 [INFO] root: Training loop in progress
# Epoch 35/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2859 - acc: 0.9836 - val_loss: 0.1478 - val_acc: 1.0000
# 2022-08-09 05:54:05,507 [INFO] root: Training loop in progress
# Epoch 36/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2872 - acc: 0.9849 - val_loss: 0.1492 - val_acc: 1.0000
# 2022-08-09 05:54:10,127 [INFO] root: Training loop in progress
# Epoch 37/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2960 - acc: 0.9857 - val_loss: 0.1485 - val_acc: 1.0000
# 2022-08-09 05:54:14,772 [INFO] root: Training loop in progress
# Epoch 38/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2753 - acc: 0.9891 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:54:19,421 [INFO] root: Training loop in progress
# Epoch 39/80
# 23/23 [==============================] - 4s 180ms/step - loss: 0.2797 - acc: 0.9891 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:54:24,084 [INFO] root: Training loop in progress
# Epoch 40/80
# 23/23 [==============================] - 4s 180ms/step - loss: 0.2914 - acc: 0.9836 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:54:28,784 [INFO] root: Training loop in progress
# Epoch 41/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2882 - acc: 0.9802 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:54:33,384 [INFO] root: Training loop in progress
# Epoch 42/80
# 23/23 [==============================] - 4s 173ms/step - loss: 0.2746 - acc: 0.9857 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:54:37,967 [INFO] root: Training loop in progress
# Epoch 43/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2994 - acc: 0.9782 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:54:42,623 [INFO] root: Training loop in progress
# Epoch 44/80
# 23/23 [==============================] - 4s 185ms/step - loss: 0.2891 - acc: 0.9837 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:54:47,531 [INFO] root: Training loop in progress
# Epoch 45/80
# 23/23 [==============================] - 4s 174ms/step - loss: 0.2767 - acc: 0.9890 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:54:52,245 [INFO] root: Training loop in progress
# Epoch 46/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2840 - acc: 0.9829 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:54:56,892 [INFO] root: Training loop in progress
# Epoch 47/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2914 - acc: 0.9863 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:55:01,530 [INFO] root: Training loop in progress
# Epoch 48/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2786 - acc: 0.9898 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:55:06,195 [INFO] root: Training loop in progress
# Epoch 49/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2801 - acc: 0.9869 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:55:10,804 [INFO] root: Training loop in progress
# Epoch 50/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2914 - acc: 0.9863 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:55:15,392 [INFO] root: Training loop in progress
# Epoch 51/80
# 23/23 [==============================] - 4s 181ms/step - loss: 0.2802 - acc: 0.9863 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:55:20,150 [INFO] root: Training loop in progress
# Epoch 52/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.3009 - acc: 0.9822 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:55:24,807 [INFO] root: Training loop in progress
# Epoch 53/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2877 - acc: 0.9905 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:55:29,470 [INFO] root: Training loop in progress
# Epoch 54/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2803 - acc: 0.9871 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:55:34,099 [INFO] root: Training loop in progress
# Epoch 55/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2882 - acc: 0.9871 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:55:38,772 [INFO] root: Training loop in progress
# Epoch 56/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2821 - acc: 0.9878 - val_loss: 0.1483 - val_acc: 1.0000
# 2022-08-09 05:55:43,491 [INFO] root: Training loop in progress
# Epoch 57/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.2773 - acc: 0.9912 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:55:48,174 [INFO] root: Training loop in progress
# Epoch 58/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.2908 - acc: 0.9842 - val_loss: 0.1491 - val_acc: 1.0000
# 2022-08-09 05:55:52,863 [INFO] root: Training loop in progress
# Epoch 59/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2938 - acc: 0.9891 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:55:57,539 [INFO] root: Training loop in progress
# Epoch 60/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.3004 - acc: 0.9844 - val_loss: 0.1485 - val_acc: 1.0000
# 2022-08-09 05:56:02,243 [INFO] root: Training loop in progress
# Epoch 61/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.2886 - acc: 0.9803 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:56:07,103 [INFO] root: Training loop in progress
# Epoch 62/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2960 - acc: 0.9857 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:56:11,826 [INFO] root: Training loop in progress
# Epoch 63/80
# 23/23 [==============================] - 4s 178ms/step - loss: 0.2883 - acc: 0.9849 - val_loss: 0.1483 - val_acc: 1.0000
# 2022-08-09 05:56:16,536 [INFO] root: Training loop in progress
# Epoch 64/80
# 23/23 [==============================] - 4s 182ms/step - loss: 0.2899 - acc: 0.9817 - val_loss: 0.1482 - val_acc: 1.0000
# 2022-08-09 05:56:21,314 [INFO] root: Training loop in progress
# Epoch 65/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2860 - acc: 0.9884 - val_loss: 0.1488 - val_acc: 1.0000
# 2022-08-09 05:56:25,987 [INFO] root: Training loop in progress
# Epoch 66/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2824 - acc: 0.9836 - val_loss: 0.1489 - val_acc: 1.0000
# 2022-08-09 05:56:30,629 [INFO] root: Training loop in progress
# Epoch 67/80
# 23/23 [==============================] - 4s 180ms/step - loss: 0.2889 - acc: 0.9841 - val_loss: 0.1490 - val_acc: 1.0000
# 2022-08-09 05:56:35,304 [INFO] root: Training loop in progress
# Epoch 68/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2902 - acc: 0.9843 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:56:40,000 [INFO] root: Training loop in progress
# Epoch 69/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2791 - acc: 0.9891 - val_loss: 0.1480 - val_acc: 1.0000
# 2022-08-09 05:56:44,896 [INFO] root: Training loop in progress
# Epoch 70/80
# 23/23 [==============================] - 4s 181ms/step - loss: 0.2895 - acc: 0.9890 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:56:49,676 [INFO] root: Training loop in progress
# Epoch 71/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2749 - acc: 0.9857 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:56:54,361 [INFO] root: Training loop in progress
# Epoch 72/80
# 23/23 [==============================] - 4s 175ms/step - loss: 0.2841 - acc: 0.9912 - val_loss: 0.1490 - val_acc: 1.0000
# 2022-08-09 05:56:58,931 [INFO] root: Training loop in progress
# Epoch 73/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2864 - acc: 0.9878 - val_loss: 0.1483 - val_acc: 1.0000
# 2022-08-09 05:57:03,552 [INFO] root: Training loop in progress
# Epoch 74/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.3003 - acc: 0.9850 - val_loss: 0.1484 - val_acc: 1.0000
# 2022-08-09 05:57:08,263 [INFO] root: Training loop in progress
# Epoch 75/80
# 23/23 [==============================] - 4s 179ms/step - loss: 0.2824 - acc: 0.9884 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:57:12,964 [INFO] root: Training loop in progress
# Epoch 76/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2845 - acc: 0.9844 - val_loss: 0.1491 - val_acc: 1.0000
# 2022-08-09 05:57:17,911 [INFO] root: Training loop in progress
# Epoch 77/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2929 - acc: 0.9850 - val_loss: 0.1480 - val_acc: 1.0000
# 2022-08-09 05:57:22,673 [INFO] root: Training loop in progress
# Epoch 78/80
# 23/23 [==============================] - 4s 177ms/step - loss: 0.2836 - acc: 0.9851 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:57:27,352 [INFO] root: Training loop in progress
# Epoch 79/80
# 23/23 [==============================] - 4s 176ms/step - loss: 0.2909 - acc: 0.9857 - val_loss: 0.1487 - val_acc: 1.0000
# 2022-08-09 05:57:31,901 [INFO] root: Training loop in progress
# Epoch 80/80
# 23/23 [==============================] - 4s 180ms/step - loss: 0.3013 - acc: 0.9781 - val_loss: 0.1486 - val_acc: 1.0000
# 2022-08-09 05:57:36,635 [INFO] root: Training loop in progress
# 2022-08-09 05:57:36,662 [INFO] root: Training loop complete.
# 2022-08-09 05:57:36,665 [INFO] root: Final model evaluation in progress.
# 2022-08-09 05:57:38,611 [INFO] root: Model evaluation in complete.
# 2022-08-09 05:57:38,611 [INFO] __main__: Total Val Loss: 0.14855116605758667
# 2022-08-09 05:57:38,611 [INFO] __main__: Total Val accuracy: 1.0
# 2022-08-09 05:57:38,611 [INFO] root: Training finished successfully.
# 2022-08-09 05:57:38,611 [INFO] __main__: Training finished successfully.
# 2022-08-09 05:57:40,981 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao classification evaluate -e $SPECS_DIR/classification_retrain_mobilenet.cfg -k $KEY
# Out:
# 2022-08-09 06:22:46,927 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 06:22:47,064 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:32: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:32: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING: From /root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/evaluate.py:111: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# INFO: Loading experiment spec at /workspace/faceclassification/specs/classification_retrain_mobilenet.cfg.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 224, 224)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 3, 226, 226)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 16, 112, 112)      432
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 16, 112, 112)      64
# _________________________________________________________________
# conv_block_relu (ReLU)       (None, 16, 112, 112)      0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, 16, 114, 114)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 16, 112, 112)      144
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 16, 112, 112)      64
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 16, 112, 112)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 56, 112, 112)      896
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 56, 112, 112)      224
# _________________________________________________________________
# conv_pw_relu_1 (ReLU)        (None, 56, 112, 112)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 56, 114, 114)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 56)        504
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 56)        224
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 56)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 56)        3136
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 56)        224
# _________________________________________________________________
# conv_pw_relu_2 (ReLU)        (None, 56, 56, 56)        0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, 56, 58, 58)        0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 56)        504
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 56)        224
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 56)        0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 120, 56, 56)       6720
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 120, 56, 56)       480
# _________________________________________________________________
# conv_pw_relu_3 (ReLU)        (None, 120, 56, 56)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 120, 58, 58)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 120, 28, 28)       1080
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 120, 28, 28)       480
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 120, 28, 28)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 152, 28, 28)       18240
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 152, 28, 28)       608
# _________________________________________________________________
# conv_pw_relu_4 (ReLU)        (None, 152, 28, 28)       0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, 152, 30, 30)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 152, 28, 28)       1368
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 152, 28, 28)       608
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 152, 28, 28)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 184, 28, 28)       27968
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 184, 28, 28)       736
# _________________________________________________________________
# conv_pw_relu_5 (ReLU)        (None, 184, 28, 28)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 184, 30, 30)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 184, 14, 14)       1656
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 184, 14, 14)       736
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 184, 14, 14)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 232, 14, 14)       42688
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 232, 14, 14)       928
# _________________________________________________________________
# conv_pw_relu_6 (ReLU)        (None, 232, 14, 14)       0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, 232, 16, 16)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 232, 14, 14)       2088
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 232, 14, 14)       928
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 232, 14, 14)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 288, 14, 14)       66816
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 288, 14, 14)       1152
# _________________________________________________________________
# conv_pw_relu_7 (ReLU)        (None, 288, 14, 14)       0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, 288, 16, 16)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 288, 14, 14)       2592
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 288, 14, 14)       1152
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 288, 14, 14)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 360, 14, 14)       103680
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 360, 14, 14)       1440
# _________________________________________________________________
# conv_pw_relu_8 (ReLU)        (None, 360, 14, 14)       0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, 360, 16, 16)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 360, 14, 14)       3240
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 360, 14, 14)       1440
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 360, 14, 14)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 384, 14, 14)       138240
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 384, 14, 14)       1536
# _________________________________________________________________
# conv_pw_relu_9 (ReLU)        (None, 384, 14, 14)       0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, 384, 16, 16)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 384, 14, 14)       3456
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 384, 14, 14)       1536
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 384, 14, 14)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 488, 14, 14)       187392
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 488, 14, 14)       1952
# _________________________________________________________________
# conv_pw_relu_10 (ReLU)       (None, 488, 14, 14)       0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, 488, 16, 16)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 488, 14, 14)       4392
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 488, 14, 14)       1952
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 488, 14, 14)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 392, 14, 14)       191296
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 392, 14, 14)       1568
# _________________________________________________________________
# conv_pw_relu_11 (ReLU)       (None, 392, 14, 14)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 392, 16, 16)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 392, 7, 7)         3528
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 392, 7, 7)         1568
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 392, 7, 7)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 632, 7, 7)         247744
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 632, 7, 7)         2528
# _________________________________________________________________
# conv_pw_relu_12 (ReLU)       (None, 632, 7, 7)         0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, 632, 9, 9)         0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 632, 7, 7)         5688
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 632, 7, 7)         2528
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 632, 7, 7)         0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 1024, 7, 7)        647168
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 1024, 7, 7)        4096
# _________________________________________________________________
# conv_pw_relu_13 (ReLU)       (None, 1024, 7, 7)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1024, 1, 1)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# predictions (Dense)          (None, 3)                 3075
# =================================================================
# Total params: 1,746,707
# Trainable params: 1,729,747
# Non-trainable params: 16,960
# _________________________________________________________________
# Found 39 images belonging to 3 classes.
# INFO: Processing dataset (evaluation): /workspace/data/test
# Evaluation Loss: 0.23523598909378052
# Evaluation Top K accuracy: 1.0
# Found 39 images belonging to 3 classes.
# INFO: Calculating per-class P/R and confusion matrix. It may take a while...
# Confusion Matrix
# [[ 9  1  0]
#  [ 0 14  0]
#  [ 0  1 14]]
# Classification Report
#               precision    recall  f1-score   support
#
#        agung       1.00      0.90      0.95        10
#       raisul       0.88      1.00      0.93        14
#        yatna       1.00      0.93      0.97        15
#
#     accuracy                           0.95        39
#    macro avg       0.96      0.94      0.95        39
# weighted avg       0.96      0.95      0.95        39
#
# 2022-08-09 06:23:11,803 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao classification export \
            -m $USER_EXPERIMENT_DIR/output_retrain/weights/mobilenet_v1_$EPOCH.tlt \
            -o $USER_EXPERIMENT_DIR/export/face_classifier_mobilenet_model.etlt \
            -k $KEY
# Out:
# 2022-08-09 06:24:23,409 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 06:24:23,543 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# /usr/local/lib/python3.6/dist-packages/numba/cuda/envvars.py:17: NumbaWarning:
# Environment variables with the 'NUMBAPRO' prefix are deprecated and consequently ignored, found use of NUMBAPRO_NVVM=/usr/local/cuda/nvvm/lib64/libnvvm.so.
#
# For more information about alternatives visit: ('http://numba.pydata.org/numba-doc/latest/cuda/overview.html', '#cudatoolkit-lookup')
#   warnings.warn(errors.NumbaWarning(msg))
# /usr/local/lib/python3.6/dist-packages/numba/cuda/envvars.py:17: NumbaWarning:
# Environment variables with the 'NUMBAPRO' prefix are deprecated and consequently ignored, found use of NUMBAPRO_LIBDEVICE=/usr/local/cuda/nvvm/libdevice/.
#
# For more information about alternatives visit: ('http://numba.pydata.org/numba-doc/latest/cuda/overview.html', '#cudatoolkit-lookup')
#   warnings.warn(errors.NumbaWarning(msg))
# 2022-08-09 06:24:35,736 [INFO] iva.common.export.keras_exporter: Using input nodes: ['input_1']
# 2022-08-09 06:24:35,736 [INFO] iva.common.export.keras_exporter: Using output nodes: ['predictions/Softmax']
# NOTE: UFF has been tested with TensorFlow 1.14.0.
# WARNING: The version of TensorFlow installed on this system is not guaranteed to work with UFF.
# DEBUG: convert reshape to flatten node
# DEBUG [/usr/local/lib/python3.6/dist-packages/uff/converters/tensorflow/converter.py:96] Marking ['predictions/Softmax'] as outputs
# 2022-08-09 06:25:09,353 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# Remove the pre-existing exported .etlt file.
# !rm -rf $LOCAL_EXPERIMENT_DIR/export/final_model.etlt
# !tao classification export \
            -m $USER_EXPERIMENT_DIR/output_retrain/weights/mobilenet_v1_$EPOCH.tlt \
            -o $USER_EXPERIMENT_DIR/export/final_model.etlt \
            -k $KEY \
            --cal_data_file $USER_EXPERIMENT_DIR/export/calibration.tensor \
            --data_type int8 \
            --batches 10 \
            --cal_cache_file $USER_EXPERIMENT_DIR/export/final_model_int8_cache.bin \
            --classmap_json $USER_EXPERIMENT_DIR/output_retrain/classmap.json \
            --gen_ds_config \
            -v
# Out:
# 2022-08-09 06:27:28,926 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 06:27:29,075 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# Using TensorFlow backend.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# /usr/local/lib/python3.6/dist-packages/numba/cuda/envvars.py:17: NumbaWarning:
# Environment variables with the 'NUMBAPRO' prefix are deprecated and consequently ignored, found use of NUMBAPRO_NVVM=/usr/local/cuda/nvvm/lib64/libnvvm.so.
#
# For more information about alternatives visit: ('http://numba.pydata.org/numba-doc/latest/cuda/overview.html', '#cudatoolkit-lookup')
#   warnings.warn(errors.NumbaWarning(msg))
# /usr/local/lib/python3.6/dist-packages/numba/cuda/envvars.py:17: NumbaWarning:
# Environment variables with the 'NUMBAPRO' prefix are deprecated and consequently ignored, found use of NUMBAPRO_LIBDEVICE=/usr/local/cuda/nvvm/libdevice/.
#
# For more information about alternatives visit: ('http://numba.pydata.org/numba-doc/latest/cuda/overview.html', '#cudatoolkit-lookup')
#   warnings.warn(errors.NumbaWarning(msg))
# 2022-08-09 06:27:40,832 [INFO] iva.common.export.keras_exporter: Using input nodes: ['input_1']
# 2022-08-09 06:27:40,833 [INFO] iva.common.export.keras_exporter: Using output nodes: ['predictions/Softmax']
# NOTE: UFF has been tested with TensorFlow 1.14.0.
# WARNING: The version of TensorFlow installed on this system is not guaranteed to work with UFF.
# DEBUG: convert reshape to flatten node
# DEBUG [/usr/local/lib/python3.6/dist-packages/uff/converters/tensorflow/converter.py:96] Marking ['predictions/Softmax'] as outputs
# 2022-08-09 06:27:53,584 [INFO] iva.common.export.base_exporter: Generating a tensorfile with random tensor images. This may work well as a profiling tool, however, it may result in inaccurate results at inference. Please generate a tensorfile using the tlt-int8-tensorfile, or provide a custom directory of images for best performance.
# 100%|███████████████████████████████████████████| 10/10 [00:07<00:00,  1.34it/s]
# 2022-08-09 06:28:01,041 [INFO] iva.common.export.keras_exporter: Calibration takes time especially if number of batches is large.
# 2022-08-09 06:28:01,827 [ERROR] modulus.export._tensorrt: Specified INT8 but not supported on platform.
# Traceback (most recent call last):
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/export.py", line 46, in <module>
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/makenet/scripts/export.py", line 42, in main
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/export/app.py", line 250, in run_export
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/export/keras_exporter.py", line 445, in export
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/core/build_wheel.runfiles/ai_infra/moduluspy/modulus/export/_tensorrt.py", line 696, in __init__
#   File "/root/.cache/bazel/_bazel_root/ed34e6d125608f91724fda23656f1726/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/core/build_wheel.runfiles/ai_infra/moduluspy/modulus/export/_tensorrt.py", line 484, in __init__
# AttributeError: Specified INT8 but not supported on platform.
# 2022-08-09 06:28:03,618 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !tao converter $USER_EXPERIMENT_DIR/export/final_model.etlt \
               -k $KEY \
               -o predictions/Softmax \
               -d 3,224,224 \
               -i nchw \
               -e $USER_EXPERIMENT_DIR/export/final_model.trt \
               -b 64
# Out:
# 2022-08-09 06:58:19,881 [INFO] root: Registry: ['nvcr.io']
# 2022-08-09 06:58:20,036 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.22.05-tf1.15.5-py3
# [INFO] [MemUsageChange] Init CUDA: CPU +195, GPU +0, now: CPU 206, GPU 375 (MiB)
# [INFO] [MemUsageSnapshot] Begin constructing builder kernel library: CPU 206 MiB, GPU 375 MiB
# [INFO] [MemUsageSnapshot] End constructing builder kernel library: CPU 270 MiB, GPU 375 MiB
# [INFO] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +264, GPU +110, now: CPU 555, GPU 485 (MiB)
# [INFO] [MemUsageChange] Init cuDNN: CPU +111, GPU +44, now: CPU 666, GPU 529 (MiB)
# [INFO] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [INFO] Some tactics do not have sufficient workspace memory to run. Increasing workspace size may increase performance, please check verbose output.
# [INFO] Detected 1 inputs and 1 output network tensors.
# [INFO] Total Host Persistent Memory: 41872
# [INFO] Total Device Persistent Memory: 6957056
# [INFO] Total Scratch Memory: 4096
# [INFO] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 11 MiB, GPU 573 MiB
# [INFO] [BlockAssignment] Algorithm ShiftNTopDown took 0.594811ms to assign 3 blocks to 30 nodes requiring 57803264 bytes.
# [INFO] Total Activation Memory: 57803264
# [INFO] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +8, now: CPU 989, GPU 675 (MiB)
# [INFO] [MemUsageChange] Init cuDNN: CPU +0, GPU +8, now: CPU 989, GPU 683 (MiB)
# [INFO] [MemUsageChange] TensorRT-managed allocation in building engine: CPU +6, GPU +7, now: CPU 6, GPU 7 (MiB)
# 2022-08-09 06:58:35,639 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.
